# %% [markdown]
# # Step 1: Tokenizing Documents

# %% [markdown]
# The first step in creating an index is tokenization. You must convert a document into a stream of tokens suitable for indexing.
# Your tokenizer should follow these steps:
# 1. Accept a directory name as a command line argument, and process all files found in that directory.
# 2. Extract the document text with an HTML parsing library, ignoring the headers at the beginning of the file and all HTML tags.
# 3. Split the text into tokens (You can use some library for regular expression matching. To learn about regular expressions go to this link http://www.rexegg.com/regex-quickstart.html).
# 4. Convert all tokens to lowercase (this is not always ideal, but indexing intelligently in a case-sensitive manner is tricky).
# 5. Apply stop-wording to the document by ignoring any tokens found in this list <font color=blue>(\\Cactus \xeon\Maryam Bashir\Information Retrieval\stoplist)</font>.
# 6. Apply stemming to the document using any standard algorithm – <font color=green> Porter, Snowball, and KStem stemmers </font> are appropriate. You should use a stemming library for this step.
# 7. Your tokenizer will write two files:
# - docids.txt – A file mapping a document's filename (without path) to a unique integer, its DOCID. Each line should be formatted with a DOCID and filename separated by a tab, as follows:<font color=blue> 1234\t32435</font>
# - termids.txt – A file mapping a token found during tokenization to a unique integer, its TERMID. Each line should be formatted with a TERMID and token separated by a tab, as follows: <font color=blue> 567\tapple </font>
#
# <font color=blue>  </font>

# %%
from bs4 import BeautifulSoup
import re
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
import random
import os
import operator
import numpy as np
#from sets import Set
#from html.parser import HTMLParser

# %%
def get_directory_path(mode):
    """
    It takes only path of folder, no file name.
    It only returns the folder which contain all the text file.
    
    Argument:
    #nothing
    
    Returns:
    dp -- directory path which contains all the txt files.
    """
    if (mode == "input"):   
        dp = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/corpus/corpus/"
    elif (mode == "output"):
        dp = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/out/"
    else:
        raise ValueError('Unspecified mode.')
        dp = None

    return dp

# %%
# Function : read_stop_list
def read_text_in_list_form(file_path):
    """
    This function takes the path of stop words file and reads it and returns a list of words.
    
    Argument:
    stop_file_path -- path should be like: path + file name.extension
        "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt".
    
    Returns:
    lineList -- list of words containg all the stop_words.
    """
    
    lst = [line.rstrip('\n') for line in open(file_path)]
    return lst

# %%
# Function = remove_html_headers
def remove_html_headers(file_path):
    """
    This function takes in path of file + file name and opens it. 
    Then it remove all the headers of html and returns the plain text.
    
    Argument:
    file_path -- concateted: path folder + file name
    
    Returns:
    soup -- the plain text of str type.
    """
    with open(file_path, encoding='utf-8',errors='ignore') as fin:
        soup = BeautifulSoup(BeautifulSoup(fin, 'html.parser').prettify()).text
        soup = soup.lower()
        return soup

# %%
# FUNCTION: split_text
def tokenize_the_text(raw_text):
    """
    This function converts raw text into list[i] i.e into tokens.
    
    Argument:
    raw_text -- class 'str' type.
    
    Returns:
    splitText -- list of unique words extracted from raw_text.
    len(splitText) -- length of words in splitText.
    """
    #lower_text = raw_text.lower()
    lower_text = raw_text
    """
    # Method 1 : Using regex
    """
    ####splitTextDig = re.split('[a-f]+',lower_text) # comment it
    splitTextAlp = str(re.findall(r"[a-z]+", lower_text))
    
    # Uncommenting This line incurrs "sns_x" type words 
    ####splitTextAlp = str(re.split(" [\s.,!?:;}{)(>]",lower_text))
    
    ####splitTextAlp = str(re.split('[0-9]+', splitTextAlp,flags=re.IGNORECASE)) #comment it
    
    splitTextAlp = list(re.split(r'\W+', (splitTextAlp)))
#     splitTextAlp = list(re.split(r' ', str(splitTextAlp)))
#     splitTextAlp = list(re.split(r'\W+', str(splitTextAlp)))

    # Now, take only those words which make sense and are greater than 3.
    splitText = [x for x in splitTextAlp if len(x) > 3]
    
    # By converting into set it will take only unique words from list.
    # Also by type casting converting back to list
    splitText = list(set(splitText))
    #splitText.sort()
    
    """
    #Method 2 : Using ntlk
    """
    #from nltk.tokenize import word_tokenize 
    #splitTextAlp = word_tokenize(lower_text)
    ###splitTextAlp = str(re.findall(r"[a-z]+", str(splitTextAlp)))
    #splitTextAlp = list(re.split('[0-9]+',str(splitTextAlp)))
    #wt = [x for x in word_tokens if len(x) > 3]
    #wt = list(set(wt))

    
    #print(type(splitText))
    #splitText = list(set(splitTextAlp).difference(splitTextDig))
    return splitText, len(splitText)
    #return wt, len(wt)

# %%
# Function : remove_stop_words
def remove_stop_words(document_words, stop_words):
    """
    This function removes the stop_list from tokens of documents.
    Stop_words are those words which occurs in abundance in text.
    
    Argument:
    document_words -- list of all the tokens/words extracted from document.
    stop_words -- list of all the stop_list extracted from file.
    
    Returns:
    cleaned -- list of all words which do not have stop_list words.
    """
    #print(type(document_words))
    #print(type(stop_words))
    cleaned_tokens_from_stop_words =  list(set(document_words) - set(stop_words))
    #cleaned_tokens_from_stop_words =  list(document_words - stop_words)
    #cleaned_tokens_from_stop_words.sort()
    return cleaned_tokens_from_stop_words

# %%
# Function : stem_words
def stem_words(tokenized_words_without_stop_words):
    """
    This function takes in list of words which do not contain stop_words.
    It uses the PorterStemmer() to reduce the word to their root words.
    
    Argument:
    removed_all_stop_words -- list of all words which do not have stop_words.
    
    Returns:
    stemmed_words -- list of words which are reduced to their origin word.
    """
    ps = PorterStemmer()
    stemmed_words = list()
    for w in tokenized_words_without_stop_words:
        stemmed_words.append(ps.stem(w))
    stemmed_words.sort()
    return stemmed_words

# %%
# Function : docid_write_to_file
def docid_write_to_file(output_file_name, doc_id, doc_name, doc_length):
    """
    This function takes in name of output file along with it's directory,
    and name of document i.e. name of text file. Then it generates a random 
    number and then writes random number and text file name to output
    file.
    
    Argument:
    output_file_name -- directory path concatenated to output file name.
    doc_name -- the name of single text file to write in output file.
    
    Returns:
    Nothing
    """
    fh = open(output_file_name, "a+")
    idx = random.randint(1,5000)
    
    line = str(doc_id) + "\t" + doc_name +  "\t" + str(doc_length)
           
    fh.write(line)
    fh.write('\n')
    
    fh.close()

# %%
# Function : termid_write_to_file
def termid_write_to_file(output_file_name, all_collection_of_words, all_collection_of_word_ids):
    """
    This function takes in name of output file along with it's directory,
    and opens in append mode, and it takes in list of all words found in
    all documents in sorted form.
    Argument:
    output_file_name -- directory path concatenated to output file name.
    list_of_all_unique_words -- list of all the unique words in sorted form.
    
    Returns:
    Nothing.
    """
    fh = open(output_file_name, "a+")
    for i in range(0,len(all_collection_of_words)):
        new_line = str(all_collection_of_word_ids[i]) + "\t" + all_collection_of_words[i]
        fh.write(new_line)
        fh.write('\n')
    fh.close()

# %%
# Function : clear_collection_from_repetition
def clear_collection_from_repetition(collection_of_all_words, stemmed_words):
    """
    This function 
    
    Argument:
    collection_of_all_words -- .
    stemmed_words -- 
    Returns:
    s -- .
    """
    
    cleaned = list(set(collection_of_all_words) - set(stemmed_words))
    common = list(set(collection_of_all_words) & set(stemmed_words))
    
    for w in range (0,len(stemmed_words)):
            collection_of_all_words.append(stemmed_words[w])
    #print(cleaned[0])
    #cleaned.sort()
    return cleaned

# %%
# Function : tokenize_the_directory_path
def tokenize_the_directory_path(path):
    """
    This function converts directory path into list[i] i.e into tokens.
    
    Argument:
    path -- class 'str' type of path of file.
    
    Returns:
    splitText -- list of unique words extracted from raw_text.
    """
    
    split_text = re.split("[/]",path)
    
    return split_text

# %%
def find_all_files_in_directory(directory):
    # Read all .txt files from directory and save to files list.
    files = []
    #r=root, d=directories, f = files
    for r, d, f in os.walk(directory):
        for file in f:
            if '.txt' in file:
                files.append(file)
            elif file == ".DS_Store": #.DS_Store
                print("\n")
                    # does nothing
                    #elif '.txt' not in file:
            else:
                files.append(file)
            
            #if '.txt' in file:
                #files.append(os.path.join(r, file))
    return files

# %% [markdown]
# # Step 2: Inverted Index

# %% [markdown]
# <font color=blue> term_index.txt - </font> An inverted index containing the file position for each occurrence of each term in the collection. Each line should contain the complete inverted list for a single term. Each line should contain a list of DOCID,POSITION values. Each line of this file should contain a TERMID followed by a space-separated list of properties as follows:
# <font color=green> 347 1542 567 432,43 456,33 456,41 </font>
# - 347: TERMID
# - 1542: Total number of occurrences of the term in the entire corpus
# - 567: Total number of documents in which the term appears
# - 432: Document Id in which term appears
# - 43: Position of term in document 432
#
# In order to support more efficient compression you must apply delta encoding to the inverted list. The first DOCID for a term and the first POSITION for a document will be stored normally. Subsequent values should be stored as the offset from the prior value.
#
# Instead of encoding an inverted list like this: <font color=green>347 1542 567 432,43 456,33 456,41 </font>
# - You should encode it like this:
# <font color=green>347 1542 567 432,43 24,33 0,8  </font>
# - <font color=red> Note that </font> in order to do this, your DOCIDs and POSITIONs must be sorted in ascending order.

# %%
def term_index_write_to_file(output_file_name, inverted_index_dictionary):
    fh = open(output_file_name, "a+")
    for term_id , dicti in inverted_index_dictionary.items():
                # term_id 
        t_id = str(term_id)
        fh.write(t_id)
        for d_id, poss in dicti.items():
            total_number_of_occurance = len(poss)
                       # doc_id          # count               # positions
            lne = "\t"+ str(d_id) +"\t"+ str(len(poss)) +"\t"+ str(poss)
            fh.write(lne)
            fh.write('\n')
    fh.close()

# %%
def create_postings_for_unhashed_ii(list_of_doc_and_terms):
    my_dict = dict()
    # One element is a tuple. 
    for tup in list_of_doc_and_terms:
        temp = list()
        key = 0
        i = 1
        #print("tup = ", tup)
        # now pick one element.
        for element in tup:
            #print("element = ", element)
            # Getting doc_id and appending it into a list
            if(np.mod(i,2) != 0): # value = doc_id
                # If key is not found.
                if (my_dict.get(key,0) == 0):
                    temp.append(element)
                else:
                    history = my_dict[key]
                    for e in range(0, len(history)):
                        temp.append(history[e])
                    temp.append(element)
            # If it is not a doc_id then it is term_id,
            # thus make a key out of it, and insert that
            # element into it.
            elif(np.mod(i,2) == 0): # key = term_id
                key = element
            i+=1
        my_dict[key] = list(set(temp))
    return my_dict

# %%
# Utility function: for document_length purpose 

#
# " output" = term_id : list_of_documents
#
def create_doc_length_txt(output_file_name, hashed_ii2):
    fh = open(output_file_name, "a+")
    for k , v in hashed_ii2.items():
        l = len(v)
        line = str(k) + "\t" + str(l) + "\t" + str(v)
        fh.write(line)
        fh.write('\n')
    fh.close()

# %% [markdown]
# # Hashed Inverted Index

# %%
# # build version 2.0 #list with dict #WOrking
# # Only puts documents in which that term_id exists
# def create_hashed_inverted_index():
#     # Get directory where all the .txt files are present.
#     directory = get_directory_path("input")
#     output_directory = get_directory_path("output")
    
#     extension = ".txt"
#     document_output_file_name = output_directory + "docid_hashed" + extension
#     term_output_file_name = output_directory + "termid_hashed" + extension
    
#     term_index_dot_txt = get_directory_path("output") + "term_index_hashed" + extension
    
#     # Load all stop words into a stop_list.
#     stop_list_path = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt"
#     stop_list = read_text_in_list_form(stop_list_path)
    
#     files = find_all_files_in_directory(directory)
#     hashed_ii = dict() ## (key:terms_id, )
#     all_collection_of_words = list()
#     all_collection_of_word_ids = list()
#     dict_for_docs = dict() ## (key: doc_id, value:terms_found_in_this_doc)
    
#     ## One doc file is opened.
#     for i in range(0,int(len(files))):
#         file_path = directory + files[i] #+ extension # no need for extension in both cases of file
#         #print(file_path)
#         all_text_without_html_headers = remove_html_headers(file_path) #str
#         tokenized_words, count_of_words = tokenize_the_text(all_text_without_html_headers) #list
#         tokenized_words_without_stop_words = remove_stop_words(tokenized_words, stop_list) #list
#         stemmed_tokens_of_words = stem_words(tokenized_words_without_stop_words) #list 
        
#         doc_id = random.randint(1,8000)
        
#         word_id_postings_list = list()
#         ## Append all words of a doc to list
#         for w in range(0,len(stemmed_tokens_of_words)):     
#             current_word = stemmed_tokens_of_words[w]
            
#             term_id = random.randint(1,1000000)
#             while term_id in hashed_ii.keys():
#                 term_id = random.randint(1,1000000)
                
#             ## If that word already present
#             if (all_collection_of_words.count(current_word)) != 0:
#                 first_occurance = all_collection_of_words.index(current_word)
#                 term_id = all_collection_of_word_ids[first_occurance]
                
#                 lst = list()
#                 history = hashed_ii[term_id] # hashed_ii[str(term_id)]
                
#                 for e in range(0, len(history)):
#                     lst.append(history[e])
#                 lst.append(doc_id)
                
#                 lst = list(set(lst))
#                 hashed_ii.update({term_id :lst})
#             else:
#                 ## already not present that word
#                 ## new place created in dictionary
#                 lst = list()
#                 lst.append((doc_id))
#                 hashed_ii[str(term_id)] = lst
                
#                 all_collection_of_words.append(current_word)
#                 all_collection_of_word_ids.append(str(term_id))
#         docid_write_to_file(document_output_file_name,doc_id,files[i])
    
#     termid_write_to_file(term_output_file_name, all_collection_of_words, all_collection_of_word_ids)
#     term_index_write_to_file(term_index_dot_txt, hashed_ii)
    
#     print("Happy Ending")
#     print(len(all_collection_of_words))

# %%
# #build version 3.0 #dictionary within dictionary
# def create_hashed_inverted_index():
#     # Get directory where all the .txt files are present.
#     directory = get_directory_path("input")
#     output_directory = get_directory_path("output")
    
#     extension = ".txt"
#     document_output_file_name = output_directory + "docid_hashed" + extension
#     term_output_file_name = output_directory + "termid_hashed" + extension
    
#     term_index_dot_txt = get_directory_path("output") + "term_index_hashed" + extension
    
#     # Load all stop words into a stop_list.
#     stop_list_path = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt"
#     stop_list = read_text_in_list_form(stop_list_path)
    
#     files = find_all_files_in_directory(directory)
#     hashed_ii = dict() ## (key:terms_id, )
#     all_collection_of_words = list()
#     all_collection_of_word_ids = list()
#     dict_for_docs = dict() ## (key: doc_id, value:terms_found_in_this_doc)
#     history = dict()
    
#     ## One doc file is opened.
#     for i in range(0,int(len(files)/500)):
#         file_path = directory + files[i] #+ extension # no need for extension in both cases of file
#         #print(file_path)
#         all_text_without_html_headers = remove_html_headers(file_path) #str
#         tokenized_words, count_of_words = tokenize_the_text(all_text_without_html_headers) #list
#         tokenized_words_without_stop_words = remove_stop_words(tokenized_words, stop_list) #list
#         stemmed_tokens_of_words = stem_words(tokenized_words_without_stop_words) #list 
        
#         doc_id = random.randint(1,8000)
        
#         word_id_postings_list = list()
#         doc_and_position_container = dict()
        
#         ## Append all words of a doc to list
#         for w in range(0,len(stemmed_tokens_of_words)):     
#             current_word = stemmed_tokens_of_words[w]
            
#             term_id = random.randint(1,100000)
#             while term_id in hashed_ii.keys():
#                 term_id = random.randint(1,100000)
                
#             ## If that word already present
#             if (all_collection_of_words.count(current_word)) != 0:
#                 first_occurance = all_collection_of_words.index(current_word)
#                 term_id = all_collection_of_word_ids[first_occurance]
                
#                 # Now history will be of type = dict()
#                 #if str(doc_id) in 
#                 history = hashed_ii[str(term_id)]
#                 lst = list()
#                 print("history = ",history)
#                 already_existed_positions = (history[str(doc_id)])
#                 #print("type = ",type(already_existed_positions))
#                 print("already_existed_positions = ", already_existed_positions)
                
#                 for e in range(0, len(already_existed_positions)):
#                         lst.append(already_existed_positions[e])
#                 #lst.append(already_existed_positions)
#                 lst.append(stemmed_tokens_of_words.index(current_word))
#                 print("lst = ", lst)
#                 history.update({str(doc_id) : lst})
#                 hashed_ii.update({str(term_id) : history})
#             else:
#                 ## already not present that word
#                 ## new place created in dictionary
#                 # key -> doc_id  par positions as values rakh di
#                 #lst = list()
#                 #lst.append(stemmed_tokens_of_words.index(current_word))
#                 hashed_ii[str(term_id)] = dict()
#                 lsr = list()
                
#                 if str(doc_id) in doc_and_position_container:
#                     temp = doc_and_position_container[str(doc_id)]
#                     for e in range(0, len(doc_and_position_container)):
#                         lsr.append(temp[e])
#                 lsr.append(stemmed_tokens_of_words.index(current_word))
#                 doc_and_position_container[str(doc_id)] = list() #stemmed_tokens_of_words.index(current_word) 
#                 doc_and_position_container[str(doc_id)] = lsr

#                 #print("doc_and_position_container = ", doc_and_position_container)
                
#                 hashed_ii[str(term_id)] = doc_and_position_container
#                 #print("hashed_ii = ", hashed_ii)
                
#                 all_collection_of_words.append(current_word)
#                 all_collection_of_word_ids.append(str(term_id))
#         docid_write_to_file(document_output_file_name,doc_id,files[i])
    
#     termid_write_to_file(term_output_file_name, all_collection_of_words, all_collection_of_word_ids)
#     term_index_write_to_file(term_index_dot_txt, hashed_ii)
    
#     print("Happy Ending")
#     print(len(all_collection_of_words))

# %%
# def doc_lengths():
#     # Get directory where all the .txt files are present.
#     directory = get_directory_path("input")
#     output_directory = get_directory_path("output")
    
#     extension = ".txt"
#     document_output_file_name = output_directory + "docid_hashed" + extension
#     term_output_file_name = output_directory + "termid_hashed" + extension
#     term_index_dot_txt = get_directory_path("output") + "term_index_hashed" + extension
    
#     # Load all stop words into a stop_list.
#     stop_list_path = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt"
#     stop_list = read_text_in_list_form(stop_list_path)
    
#     files = find_all_files_in_directory(directory)
#     hashed_ii = dict() ## (key:terms_id, )
#     all_collection_of_words = list()
#     all_collection_of_word_ids = list()
#     dict_for_docs = dict() ## (key: doc_id, value:terms_found_in_this_doc)
#     history = dict()
    
#     output_doc_length_file = output_directory + "doc_lengths" + extension
    
#     fh = open(output_doc_length_file, "a+")

#     ## One doc file is opened.
#     for i in range(0,int(len(files)/200)):
#         file_path = directory + files[i] #+ extension # no need for extension in both cases of file
#         #print(file_path)
#         all_text_without_html_headers = remove_html_headers(file_path) #str
#         tokenized_words, count_of_words = tokenize_the_text(all_text_without_html_headers) #list
#         tokenized_words_without_stop_words = remove_stop_words(tokenized_words, stop_list) #list
#         stemmed_tokens_of_words = stem_words(tokenized_words_without_stop_words) #list 
#         l = len(stemmed_tokens_of_words)
#         new_line = str(l)?
#         fh.write(new_line)
#         fh.write('\n')
#     fh.close()

# %%
# doc_lengths()

# %%
# #build version 4.0 #dictionary within dictionary #WORKING
# def create_hashed_inverted_index():
#     # Get directory where all the .txt files are present.
#     directory = get_directory_path("input")
#     output_directory = get_directory_path("output")
    
#     extension = ".txt"
#     document_output_file_name = output_directory + "docid_hashed" + extension
#     term_output_file_name = output_directory + "termid_hashed" + extension
#     term_index_dot_txt = get_directory_path("output") + "term_index_hashed" + extension
    
#     # Load all stop words into a stop_list.
#     stop_list_path = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt"
#     stop_list = read_text_in_list_form(stop_list_path)
    
#     files = find_all_files_in_directory(directory)
#     hashed_ii = dict() ## (key:terms_id, )
#     all_collection_of_words = list()
#     all_collection_of_word_ids = list()
#     dict_for_docs = dict() ## (key: doc_id, value:terms_found_in_this_doc)
#     history = dict()
    
#     ## One doc file is opened.
#     for i in range(0,int(len(files)/200)):
#         #print(files[i])
#         #print("\n", i)
#         file_path = directory + files[i] #+ extension # no need for extension in both cases of file
#         #print(file_path)
#         all_text_without_html_headers = remove_html_headers(file_path) #str
#         tokenized_words, count_of_words = tokenize_the_text(all_text_without_html_headers) #list
#         tokenized_words_without_stop_words = remove_stop_words(tokenized_words, stop_list) #list
#         stemmed_tokens_of_words = stem_words(tokenized_words_without_stop_words) #list 
        
#         doc_id = random.randint(1,8000)
#         doc_and_position_container = dict()

#         ## Append all words of a doc to list
        
#         for w in range(0,len(stemmed_tokens_of_words)):     
#             current_word = stemmed_tokens_of_words[w]
#             term_id = random.randint(1,1000000)
#             while term_id in hashed_ii.keys():
#                 term_id = random.randint(1,100000)
                
#             ## If that word already present
#             if (all_collection_of_words.count(current_word)) != 0:
#                 first_occurance = all_collection_of_words.index(current_word)
#                 term_id = all_collection_of_word_ids[first_occurance]
#                 history = dict()
#                 history = hashed_ii[str(term_id)] 
                
#                 for d_id, positions_list in history.items():
#                     #if d_id == str(doc_id):
#                         already_existed_positions = list()
#                         already_existed_positions = positions_list #(history[d_id])
#                     #print("positions_list ", positions_list)
#                     #lst = list()
#                     #for e in range(0, len(already_existed_positions)):
#                     #    lst.append(already_existed_positions[e])
#                         already_existed_positions.append(stemmed_tokens_of_words.index(current_word,w,len(stemmed_tokens_of_words)))
#                         #print("already_existed = ",d_id, " ", already_existed_positions)
#                         #print(d_id,term_id, current_word)
#                     #lst.append(stemmed_tokens_of_words.index(current_word,w,len(stemmed_tokens_of_words)))
#                     #history[kys] = lst
#                         #history.update({d_id : already_existed_positions})
#                         history[str(d_id)] = already_existed_positions
#                     #lst = list(set(lst))
#                 #hashed_ii[str(term_id)] = history
#                 #history.update({(doc_id) : lst})
#                         hashed_ii[str(term_id)] = history
#                         #hashed_ii.update({str(term_id) : history})  # <--- ye line dekh zara
#                         #hashed_ii.update(history)
#                 #print("nai idher, if mein")
#             ## If already not present that word
#             else:
#                 all_collection_of_words.append(current_word)
#                 all_collection_of_word_ids.append(str(term_id))
#                 lsr = list()
#                 position = stemmed_tokens_of_words.index(current_word) 
#                 #print("positions = " , position)
#                 lsr.append(position)
#                 doc_and_position_container = dict()
#                 doc_and_position_container[str(doc_id)] = lsr
#                 hashed_ii[str(term_id)] = dict()
#                 #hashed_ii[str(term_id)] = doc_and_position_container
#                 hashed_ii.update({str(term_id) : doc_and_position_container})
#                 #print("\nKia Ider")
#                 #print("hashed_ii = ", hashed_ii)
#         docid_write_to_file(document_output_file_name,doc_id,files[i])
#     print("hashed_ii = ", hashed_ii)
#     termid_write_to_file(term_output_file_name, all_collection_of_words, all_collection_of_word_ids)
#     term_index_write_to_file(term_index_dot_txt, hashed_ii)
    
#     print("Happy Ending")
#     print(len(all_collection_of_words))

# %%
#build version 5.0 #dictionary within dictionary #Correct Output
def create_hashed_inverted_index():
    # Get directory where all the .txt files are present.
    directory = get_directory_path("input")
    output_directory = get_directory_path("output")
    
    extension = ".txt"
    document_output_file_name = output_directory + "docid_hashed" + extension
    term_output_file_name = output_directory + "termid_hashed" + extension
    term_index_dot_txt = get_directory_path("output") + "term_index_hashed" + extension
    document_frequency_file = get_directory_path("output") + "document_frequency" + extension
    document_length = get_directory_path("output") + "document_length" + extension
    
    # Load all stop words into a stop_list.
    stop_list_path = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt"
    stop_list = read_text_in_list_form(stop_list_path)
    
    files = find_all_files_in_directory(directory)
    hashed_ii = dict() ## (key:{terms_id: {doc_id: positions}} )
    hashed_ii2 = dict()
    all_collection_of_words = list()
    all_collection_of_word_ids = list()
    dict_for_docs = dict() ## (key: term_id, value:docs_list)
    history = dict()
    
    ## One doc file is opened.
    for i in range(0,int(len(files)/200)):
        #print(files[i])
        #print("\n", i)
        file_path = directory + files[i] #+ extension # no need for extension in both cases of file
        #print(file_path)
        all_text_without_html_headers = remove_html_headers(file_path) #str
        tokenized_words, count_of_words = tokenize_the_text(all_text_without_html_headers) #list
        tokenized_words_without_stop_words = remove_stop_words(tokenized_words, stop_list) #list
        stemmed_tokens_of_words = stem_words(tokenized_words_without_stop_words) #list 
        
        doc_id = random.randint(1,8000)
        doc_and_position_container = dict()

        ## Append all words of a doc to list
        
        for w in range(0,len(stemmed_tokens_of_words)):     
            current_word = stemmed_tokens_of_words[w]
            
            term_id = random.randint(1,1000000)
            while term_id in hashed_ii.keys():
                term_id = random.randint(1,100000)
            doc_and_position_container = dict()
            ## If that word already present
            if (all_collection_of_words.count(current_word)) != 0:
                first_occurance = all_collection_of_words.index(current_word)
                term_id = all_collection_of_word_ids[first_occurance]
                
                print("\nFound for term_id = ", term_id," doc_id = ", doc_id)
                
                #print("history = ", history)
                
                ####### This part: for term and it's documents in which ot exists. ######
                # In short, later used for doc_length
                lst2 = list()
                history2 = hashed_ii2[str(term_id)]
                
                
                for e in range(0, len(history2)):
                    lst2.append(history2[e])
                lst2.append(doc_id)
                
                lst2 = list(set(lst2))
                hashed_ii2.update({term_id :lst2})
                ########################################################################
                
                #- new dict bna k uske ander new entry kron new doc_id ki
                #- yahan per ye bhe dekha jae k kia wo doc_id mein pehli mil gya hai (word repeat zror 
                #magar new document mein )
                #- aur agar usi same document mein hai tou, matlab doc_id as key already mujood hai.
                history = dict()
                history = hashed_ii[str(term_id)]
                
                ### -> Word repeat tou lazmi huva hai.
                
                # Case: Agar usi document mein dobara word mil gaya hai, tou wo doc_id tou pehle se mujood hoga
                if str(doc_id) in history:
                    for d_id, positions in history.items():
                        if d_id == str(doc_id):
                            positions_list = history[str(d_id)]
                            already_existed_positions = list()
                            already_existed_positions = positions_list #(history[d_id])
                            already_existed_positions.append(stemmed_tokens_of_words.index(current_word,w,len(stemmed_tokens_of_words)))
                            #print("Before updating HISTORY", history)
                            history.update({(d_id) :  already_existed_positions})
                            #print("After updating HISTORY", history)
                            #print("history = ", history)

                            #print("Before updating hashed_ii", hashed_ii)
                            hashed_ii.update({str(term_id): history})
                            #print("After updating hashed_ii", hashed_ii)
                else: #agar naya doc aya hai tou, new doc ki key bnani paregi.
                    # naya doc hai, tou new key bnani paregi doc_id ki history ki dict mein
                    first_time_position_found_in_new_doc = list()
                    first_time_position_found_in_new_doc.append(stemmed_tokens_of_words.index(current_word,w,len(stemmed_tokens_of_words)))
                    history[str(doc_id)] = first_time_position_found_in_new_doc
                    hashed_ii.update({str(term_id): history})
                    #history.update({(d_id) :  first_time_position_found_in_new_doc})
            ## If already NOT present that word
            else:
                all_collection_of_words.append(current_word)
                all_collection_of_word_ids.append(str(term_id))
                
                ####### This part: for term and it's documents in which ot exists. ####
                lst2 = list()
                lst2.append((doc_id))
                hashed_ii2[str(term_id)] = lst2
                ####################################################################
                
                lsr = list()
                position = stemmed_tokens_of_words.index(current_word) 
                #print("positions = " , position)
                lsr.append(position)
                doc_and_position_container = dict()
                # usi same doc_id k ander pos change ki ja raha ha
                doc_and_position_container[str(doc_id)] = lsr
                #print("doc_and_position_container = ", doc_and_position_container)
                #hashed_ii[str(term_id)] = dict()
                #print("Before update", hashed_ii)
                hashed_ii.update({str(term_id) : doc_and_position_container})
                #print("\nAfter update", hashed_ii)
        docid_write_to_file(document_output_file_name, doc_id, files[i], len(stemmed_tokens_of_words))
    print("hashed_ii = ", hashed_ii)
    termid_write_to_file(term_output_file_name, all_collection_of_words, all_collection_of_word_ids)
    create_doc_length_txt(document_frequency_file, hashed_ii2)
    term_index_write_to_file(term_index_dot_txt, hashed_ii)
    
    print("Happy Ending")
    print(len(all_collection_of_words))

# %% [markdown]
# To create hashed inverted index execute following function.

# %%
create_hashed_inverted_index()
# Out:
# Found for term_id =  715980  doc_id =  6616
#
# Found for term_id =  502717  doc_id =  6616
#
# Found for term_id =  951404  doc_id =  6616
#
# Found for term_id =  951404  doc_id =  6616
#
# Found for term_id =  868797  doc_id =  6616
#
# Found for term_id =  340298  doc_id =  6616
#
# Found for term_id =  941926  doc_id =  6616
#
# Found for term_id =  716541  doc_id =  6616
#
# Found for term_id =  679164  doc_id =  6616
#
# Found for term_id =  172532  doc_id =  6616
#
# Found for term_id =  846502  doc_id =  6616
#
# Found for term_id =  960992  doc_id =  4935
#
# Found for term_id =  960992  doc_id =  4935
#
# Found for term_id =  243013  doc_id =  4935
#
# Found for term_id =  243013  doc_id =  4935
#
# Found for term_id =  964280  doc_id =  4935
#
# Found for term_id =  133999  doc_id =  4935
#
# Found for term_id =  801954  doc_id =  4935
#
# Found for term_id =  236802  doc_id =  4935
#
# Found for term_id =  489397  doc_id =  4935
#
# Found for term_id =  300910  doc_id =  4935
#
# Found for term_id =  158256  doc_id =  4935
#
# Found for term_id =  976635  doc_id =  4935
#
# Found for term_id =  764183  doc_id =  4935
#
# Found for term_id =  807601  doc_id =  4935
#
# Found for term_id =  438323  doc_id =  4935
#
# Found for term_id =  825820  doc_id =  4935
#
# Found for term_id =  451014  doc_id =  4935
#
# Found for term_id =  843788  doc_id =  4935
#
# Found for term_id =  884605  doc_id =  4935
#
# Found for term_id =  852425  doc_id =  4935
#
# Found for term_id =  405095  doc_id =  4935
#
# Found for term_id =  107714  doc_id =  4935
#
# Found for term_id =  100105  doc_id =  4935
#
# Found for term_id =  444535  doc_id =  4935
#
# Found for term_id =  491535  doc_id =  4935
#
# Found for term_id =  967330  doc_id =  4935
#
# Found for term_id =  422377  doc_id =  4935
#
# Found for term_id =  361696  doc_id =  4935
#
# Found for term_id =  823403  doc_id =  4935
#
# Found for term_id =  349007  doc_id =  4935
#
# Found for term_id =  78767  doc_id =  4935
#
# Found for term_id =  595952  doc_id =  4935
#
# Found for term_id =  363714  doc_id =  4935
#
# Found for term_id =  719819  doc_id =  4935
#
# Found for term_id =  499926  doc_id =  4935
#
# Found for term_id =  502717  doc_id =  4935
#
# Found for term_id =  502717  doc_id =  4935
#
# Found for term_id =  260089  doc_id =  4935
#
# Found for term_id =  802634  doc_id =  4935
#
# Found for term_id =  912007  doc_id =  4935
#
# Found for term_id =  541807  doc_id =  4935
#
# Found for term_id =  971844  doc_id =  4935
#
# Found for term_id =  612460  doc_id =  4935
#
# Found for term_id =  339807  doc_id =  4935
#
# Found for term_id =  430292  doc_id =  4935
#
# Found for term_id =  359329  doc_id =  4935
#
# Found for term_id =  750534  doc_id =  4935
#
# Found for term_id =  188285  doc_id =  4935
#
# Found for term_id =  730448  doc_id =  4935
#
# Found for term_id =  398458  doc_id =  4935
#
# Found for term_id =  104810  doc_id =  4935
#
# Found for term_id =  550512  doc_id =  4935
#
# Found for term_id =  348342  doc_id =  4935
#
# Found for term_id =  744987  doc_id =  4935
#
# Found for term_id =  448061  doc_id =  4935
#
# Found for term_id =  241604  doc_id =  4935
#
# Found for term_id =  840857  doc_id =  4935
#
# Found for term_id =  594947  doc_id =  4935
#
# Found for term_id =  927640  doc_id =  4935
#
# Found for term_id =  927640  doc_id =  4935
#
# Found for term_id =  685502  doc_id =  4935
#
# Found for term_id =  340298  doc_id =  4935
#
# Found for term_id =  325447  doc_id =  4935
#
# Found for term_id =  292275  doc_id =  4935
#
# Found for term_id =  752311  doc_id =  4935
#
# Found for term_id =  929814  doc_id =  4935
#
# Found for term_id =  948041  doc_id =  4935
#
# Found for term_id =  211445  doc_id =  4935
#
# Found for term_id =  211445  doc_id =  4935
#
# Found for term_id =  941926  doc_id =  4935
#
# Found for term_id =  541607  doc_id =  4935
#
# Found for term_id =  307613  doc_id =  4935
#
# Found for term_id =  201050  doc_id =  4935
#
# Found for term_id =  674519  doc_id =  4935
#
# Found for term_id =  92128  doc_id =  4935
#
# Found for term_id =  78543  doc_id =  4935
#
# Found for term_id =  95595  doc_id =  4935
#
# Found for term_id =  997803  doc_id =  4935
#
# Found for term_id =  498676  doc_id =  4935
#
# Found for term_id =  2267  doc_id =  4935
#
# Found for term_id =  735963  doc_id =  4935
#
# Found for term_id =  578213  doc_id =  4935
#
# Found for term_id =  423919  doc_id =  4935
#
# Found for term_id =  393522  doc_id =  4935
#
# Found for term_id =  544216  doc_id =  4935
#
# Found for term_id =  292146  doc_id =  4935
#
# Found for term_id =  468020  doc_id =  4935
#
# Found for term_id =  960992  doc_id =  2613
#
# Found for term_id =  964280  doc_id =  2613
#
# Found for term_id =  801954  doc_id =  2613
#
# Found for term_id =  236802  doc_id =  2613
#
# Found for term_id =  489397  doc_id =  2613
#
# Found for term_id =  14910  doc_id =  2613
#
# Found for term_id =  277016  doc_id =  2613
#
# Found for term_id =  117907  doc_id =  2613
#
# Found for term_id =  526846  doc_id =  2613
#
# Found for term_id =  892701  doc_id =  2613
#
# Found for term_id =  779819  doc_id =  2613
#
# Found for term_id =  158256  doc_id =  2613
#
# Found for term_id =  463074  doc_id =  2613
#
# Found for term_id =  857554  doc_id =  2613
#
# Found for term_id =  345675  doc_id =  2613
#
# Found for term_id =  807601  doc_id =  2613
#
# Found for term_id =  438323  doc_id =  2613
#
# Found for term_id =  825820  doc_id =  2613
#
# Found for term_id =  825820  doc_id =  2613
#
# Found for term_id =  451014  doc_id =  2613
#
# Found for term_id =  843788  doc_id =  2613
#
# Found for term_id =  884605  doc_id =  2613
#
# Found for term_id =  852425  doc_id =  2613
#
# Found for term_id =  75858  doc_id =  2613
#
# Found for term_id =  405095  doc_id =  2613
#
# Found for term_id =  405095  doc_id =  2613
#
# Found for term_id =  162920  doc_id =  2613
#
# Found for term_id =  50768  doc_id =  2613
#
# Found for term_id =  107714  doc_id =  2613
#
# Found for term_id =  446983  doc_id =  2613
#
# Found for term_id =  523969  doc_id =  2613
#
# Found for term_id =  147166  doc_id =  2613
#
# Found for term_id =  100105  doc_id =  2613
#
# Found for term_id =  271880  doc_id =  2613
#
# Found for term_id =  491535  doc_id =  2613
#
# Found for term_id =  967330  doc_id =  2613
#
# Found for term_id =  76565  doc_id =  2613
#
# Found for term_id =  155499  doc_id =  2613
#
# Found for term_id =  885490  doc_id =  2613
#
# Found for term_id =  191447  doc_id =  2613
#
# Found for term_id =  349007  doc_id =  2613
#
# Found for term_id =  349007  doc_id =  2613
#
# Found for term_id =  510442  doc_id =  2613
#
# Found for term_id =  595952  doc_id =  2613
#
# Found for term_id =  723949  doc_id =  2613
#
# Found for term_id =  67539  doc_id =  2613
#
# Found for term_id =  547374  doc_id =  2613
#
# Found for term_id =  499926  doc_id =  2613
#
# Found for term_id =  502717  doc_id =  2613
#
# Found for term_id =  502717  doc_id =  2613
#
# Found for term_id =  541807  doc_id =  2613
#
# Found for term_id =  435680  doc_id =  2613
#
# Found for term_id =  612460  doc_id =  2613
#
# Found for term_id =  199048  doc_id =  2613
#
# Found for term_id =  430292  doc_id =  2613
#
# Found for term_id =  199705  doc_id =  2613
#
# Found for term_id =  199705  doc_id =  2613
#
# Found for term_id =  559204  doc_id =  2613
#
# Found for term_id =  750534  doc_id =  2613
#
# Found for term_id =  341944  doc_id =  2613
#
# Found for term_id =  635609  doc_id =  2613
#
# Found for term_id =  188285  doc_id =  2613
#
# Found for term_id =  281494  doc_id =  2613
#
# Found for term_id =  986380  doc_id =  2613
#
# Found for term_id =  986380  doc_id =  2613
#
# Found for term_id =  508366  doc_id =  2613
#
# Found for term_id =  550512  doc_id =  2613
#
# Found for term_id =  114606  doc_id =  2613
#
# Found for term_id =  729775  doc_id =  2613
#
# Found for term_id =  348342  doc_id =  2613
#
# Found for term_id =  448061  doc_id =  2613
#
# Found for term_id =  241604  doc_id =  2613
#
# Found for term_id =  840857  doc_id =  2613
#
# Found for term_id =  881857  doc_id =  2613
#
# Found for term_id =  103634  doc_id =  2613
#
# Found for term_id =  511995  doc_id =  2613
#
# Found for term_id =  927640  doc_id =  2613
#
# Found for term_id =  927640  doc_id =  2613
#
# Found for term_id =  685502  doc_id =  2613
#
# Found for term_id =  484781  doc_id =  2613
#
# Found for term_id =  325049  doc_id =  2613
#
# Found for term_id =  340298  doc_id =  2613
#
# Found for term_id =  325447  doc_id =  2613
#
# Found for term_id =  493434  doc_id =  2613
#
# Found for term_id =  292275  doc_id =  2613
#
# Found for term_id =  729491  doc_id =  2613
#
# Found for term_id =  752311  doc_id =  2613
#
# Found for term_id =  929814  doc_id =  2613
#
# Found for term_id =  948041  doc_id =  2613
#
# Found for term_id =  827588  doc_id =  2613
#
# Found for term_id =  211445  doc_id =  2613
#
# Found for term_id =  211445  doc_id =  2613
#
# Found for term_id =  941926  doc_id =  2613
#
# Found for term_id =  796353  doc_id =  2613
#
# Found for term_id =  307613  doc_id =  2613
#
# Found for term_id =  674519  doc_id =  2613
#
# Found for term_id =  92128  doc_id =  2613
#
# Found for term_id =  870556  doc_id =  2613
#
# Found for term_id =  95595  doc_id =  2613
#
# Found for term_id =  660687  doc_id =  2613
#
# Found for term_id =  997803  doc_id =  2613
#
# Found for term_id =  498676  doc_id =  2613
#
# Found for term_id =  2267  doc_id =  2613
#
# Found for term_id =  132993  doc_id =  2613
#
# Found for term_id =  921721  doc_id =  2613
#
# Found for term_id =  578213  doc_id =  2613
#
# Found for term_id =  423919  doc_id =  2613
#
# Found for term_id =  393522  doc_id =  2613
#
# Found for term_id =  404693  doc_id =  2613
# Found for term_id =  383262  doc_id =  5963
#
# Found for term_id =  964280  doc_id =  5963
#
# Found for term_id =  720123  doc_id =  5963
#
# Found for term_id =  459513  doc_id =  5963
#
# Found for term_id =  801954  doc_id =  5963
#
# Found for term_id =  236802  doc_id =  5963
#
# Found for term_id =  489397  doc_id =  5963
#
# Found for term_id =  14910  doc_id =  5963
#
# Found for term_id =  640048  doc_id =  5963
#
# Found for term_id =  38735  doc_id =  5963
#
# Found for term_id =  117907  doc_id =  5963
#
# Found for term_id =  526846  doc_id =  5963
#
# Found for term_id =  137547  doc_id =  5963
#
# Found for term_id =  922343  doc_id =  5963
#
# Found for term_id =  922343  doc_id =  5963
#
# Found for term_id =  779819  doc_id =  5963
#
# Found for term_id =  534445  doc_id =  5963
#
# Found for term_id =  534445  doc_id =  5963
#
# Found for term_id =  576804  doc_id =  5963
#
# Found for term_id =  463074  doc_id =  5963
#
# Found for term_id =  857554  doc_id =  5963
#
# Found for term_id =  345675  doc_id =  5963
#
# Found for term_id =  992234  doc_id =  5963
#
# Found for term_id =  771110  doc_id =  5963
#
# Found for term_id =  706154  doc_id =  5963
#
# Found for term_id =  706154  doc_id =  5963
#
# Found for term_id =  807601  doc_id =  5963
#
# Found for term_id =  438323  doc_id =  5963
#
# Found for term_id =  699230  doc_id =  5963
#
# Found for term_id =  825820  doc_id =  5963
#
# Found for term_id =  806041  doc_id =  5963
#
# Found for term_id =  172738  doc_id =  5963
#
# Found for term_id =  451014  doc_id =  5963
#
# Found for term_id =  852425  doc_id =  5963
#
# Found for term_id =  75858  doc_id =  5963
#
# Found for term_id =  405095  doc_id =  5963
#
# Found for term_id =  162920  doc_id =  5963
#
# Found for term_id =  162920  doc_id =  5963
#
# Found for term_id =  50768  doc_id =  5963
#
# Found for term_id =  223626  doc_id =  5963
#
# Found for term_id =  107714  doc_id =  5963
#
# Found for term_id =  340641  doc_id =  5963
#
# Found for term_id =  147166  doc_id =  5963
#
# Found for term_id =  147166  doc_id =  5963
#
# Found for term_id =  100105  doc_id =  5963
#
# Found for term_id =  191720  doc_id =  5963
#
# Found for term_id =  806729  doc_id =  5963
#
# Found for term_id =  271880  doc_id =  5963
#
# Found for term_id =  444535  doc_id =  5963
#
# Found for term_id =  491535  doc_id =  5963
#
# Found for term_id =  188130  doc_id =  5963
#
# Found for term_id =  208555  doc_id =  5963
#
# Found for term_id =  654940  doc_id =  5963
#
# Found for term_id =  654940  doc_id =  5963
#
# Found for term_id =  568989  doc_id =  5963
#
# Found for term_id =  568989  doc_id =  5963
#
# Found for term_id =  496892  doc_id =  5963
#
# Found for term_id =  278221  doc_id =  5963
#
# Found for term_id =  76565  doc_id =  5963
#
# Found for term_id =  686192  doc_id =  5963
#
# Found for term_id =  682092  doc_id =  5963
#
# Found for term_id =  422377  doc_id =  5963
#
# Found for term_id =  191447  doc_id =  5963
#
# Found for term_id =  137089  doc_id =  5963
#
# Found for term_id =  349007  doc_id =  5963
#
# Found for term_id =  78767  doc_id =  5963
#
# Found for term_id =  510442  doc_id =  5963
#
# Found for term_id =  586775  doc_id =  5963
#
# Found for term_id =  891326  doc_id =  5963
#
# Found for term_id =  595952  doc_id =  5963
#
# Found for term_id =  878875  doc_id =  5963
#
# Found for term_id =  363714  doc_id =  5963
#
# Found for term_id =  623660  doc_id =  5963
#
# Found for term_id =  514707  doc_id =  5963
#
# Found for term_id =  132636  doc_id =  5963
#
# Found for term_id =  444380  doc_id =  5963
#
# Found for term_id =  67539  doc_id =  5963
#
# Found for term_id =  67539  doc_id =  5963
#
# Found for term_id =  547374  doc_id =  5963
#
# Found for term_id =  758289  doc_id =  5963
#
# Found for term_id =  595988  doc_id =  5963
#
# Found for term_id =  499926  doc_id =  5963
#
# Found for term_id =  502717  doc_id =  5963
#
# Found for term_id =  502717  doc_id =  5963
#
# Found for term_id =  61269  doc_id =  5963
#
# Found for term_id =  802634  doc_id =  5963
#
# Found for term_id =  808094  doc_id =  5963
#
# Found for term_id =  971844  doc_id =  5963
#
# Found for term_id =  330631  doc_id =  5963
#
# Found for term_id =  433102  doc_id =  5963
#
# Found for term_id =  612460  doc_id =  5963
#
# Found for term_id =  951580  doc_id =  5963
#
# Found for term_id =  88373  doc_id =  5963
#
# Found for term_id =  886652  doc_id =  5963
#
# Found for term_id =  430292  doc_id =  5963
#
# Found for term_id =  359329  doc_id =  5963
#
# Found for term_id =  359329  doc_id =  5963
#
# Found for term_id =  135683  doc_id =  5963
#
# Found for term_id =  559204  doc_id =  5963
#
# Found for term_id =  750534  doc_id =  5963
#
# Found for term_id =  637433  doc_id =  5963
#
# Found for term_id =  637433  doc_id =  5963
#
# Found for term_id =  341944  doc_id =  5963
#
# Found for term_id =  517056  doc_id =  5963
#
# Found for term_id =  540089  doc_id =  5963
#
# Found for term_id =  635609  doc_id =  5963
#
# Found for term_id =  635609  doc_id =  5963
#
# Found for term_id =  493315  doc_id =  5963
#
# Found for term_id =  188285  doc_id =  5963
#
# Found for term_id =  281494  doc_id =  5963
#
# Found for term_id =  730448  doc_id =  5963
#
# Found for term_id =  986380  doc_id =  5963
#
# Found for term_id =  104810  doc_id =  5963
#
# Found for term_id =  114606  doc_id =  5963
#
# Found for term_id =  349578  doc_id =  5963
#
# Found for term_id =  513330  doc_id =  5963
#
# Found for term_id =  729775  doc_id =  5963
#
# Found for term_id =  729775  doc_id =  5963
#
# Found for term_id =  348342  doc_id =  5963
#
# Found for term_id =  594863  doc_id =  5963
#
# Found for term_id =  591461  doc_id =  5963
#
# Found for term_id =  666814  doc_id =  5963
#
# Found for term_id =  794445  doc_id =  5963
#
# Found for term_id =  493003  doc_id =  5963
#
# Found for term_id =  241604  doc_id =  5963
#
# Found for term_id =  241604  doc_id =  5963
#
# Found for term_id =  241604  doc_id =  5963
#
# Found for term_id =  241604  doc_id =  5963
#
# Found for term_id =  840857  doc_id =  5963
#
# Found for term_id =  840857  doc_id =  5963
#
# Found for term_id =  881857  doc_id =  5963
#
# Found for term_id =  820846  doc_id =  5963
#
# Found for term_id =  685502  doc_id =  5963
#
# Found for term_id =  484781  doc_id =  5963
#
# Found for term_id =  484781  doc_id =  5963
#
# Found for term_id =  325049  doc_id =  5963
#
# Found for term_id =  340298  doc_id =  5963
#
# Found for term_id =  450569  doc_id =  5963
#
# Found for term_id =  515184  doc_id =  5963
#
# Found for term_id =  227096  doc_id =  5963
#
# Found for term_id =  580057  doc_id =  5963
#
# Found for term_id =  325447  doc_id =  5963
#
# Found for term_id =  136589  doc_id =  5963
#
# Found for term_id =  292275  doc_id =  5963
#
# Found for term_id =  292275  doc_id =  5963
#
# Found for term_id =  752311  doc_id =  5963
#
# Found for term_id =  929814  doc_id =  5963
#
# Found for term_id =  960808  doc_id =  5963
#
# Found for term_id =  948041  doc_id =  5963
#
# Found for term_id =  827588  doc_id =  5963
#
# Found for term_id =  727536  doc_id =  5963
#
# Found for term_id =  966973  doc_id =  5963
#
# Found for term_id =  941926  doc_id =  5963
#
# Found for term_id =  805455  doc_id =  5963
#
# Found for term_id =  921412  doc_id =  5963
#
# Found for term_id =  73701  doc_id =  5963
#
# Found for term_id =  541607  doc_id =  5963
#
# Found for term_id =  541607  doc_id =  5963
#
# Found for term_id =  796353  doc_id =  5963
#
# Found for term_id =  201050  doc_id =  5963
#
# Found for term_id =  83607  doc_id =  5963
#
# Found for term_id =  77567  doc_id =  5963
#
# Found for term_id =  977618  doc_id =  5963
#
# Found for term_id =  977618  doc_id =  5963
#
# Found for term_id =  851696  doc_id =  5963
#
# Found for term_id =  674519  doc_id =  5963
#
# Found for term_id =  951312  doc_id =  5963
#
# Found for term_id =  154767  doc_id =  5963
#
# Found for term_id =  322122  doc_id =  5963
#
# Found for term_id =  92128  doc_id =  5963
#
# Found for term_id =  973397  doc_id =  5963
#
# Found for term_id =  55900  doc_id =  5963
#
# Found for term_id =  55900  doc_id =  5963
#
# Found for term_id =  870556  doc_id =  5963
#
# Found for term_id =  870556  doc_id =  5963
#
# Found for term_id =  315832  doc_id =  5963
#
# Found for term_id =  95595  doc_id =  5963
#
# Found for term_id =  997803  doc_id =  5963
#
# Found for term_id =  498676  doc_id =  5963
#
# Found for term_id =  807958  doc_id =  5963
#
# Found for term_id =  755303  doc_id =  5963
#
# Found for term_id =  511418  doc_id =  5963
#
# Found for term_id =  2267  doc_id =  5963
#
# Found for term_id =  2267  doc_id =  5963
#
# Found for term_id =  982001  doc_id =  5963
#
# Found for term_id =  670235  doc_id =  5963
#
# Found for term_id =  510008  doc_id =  5963
#
# Found for term_id =  395327  doc_id =  5963
#
# Found for term_id =  735963  doc_id =  5963
#
# Found for term_id =  735963  doc_id =  5963
#
# Found for term_id =  561972  doc_id =  5963
#
# Found for term_id =  921721  doc_id =  5963
#
# Found for term_id =  398631  doc_id =  5963
#
# Found for term_id =  423919  doc_id =  5963
#
# Found for term_id =  423919  doc_id =  5963
#
# Found for term_id =  993096  doc_id =  5963
#
# Found for term_id =  993096  doc_id =  5963
#
# Found for term_id =  993096  doc_id =  5963
#
# Found for term_id =  393522  doc_id =  5963
#
# Found for term_id =  301308  doc_id =  5963
#
# Found for term_id =  871349  doc_id =  5963
#
# Found for term_id =  901002  doc_id =  5963
#
# Found for term_id =  648102  doc_id =  5963
#
# Found for term_id =  648102  doc_id =  5963
#
# Found for term_id =  257628  doc_id =  5963
#
# Found for term_id =  468020  doc_id =  5963
#
# Found for term_id =  626096  doc_id =  5963
# Found for term_id =  960992  doc_id =  1799
#
# Found for term_id =  512585  doc_id =  1799
#
# Found for term_id =  964280  doc_id =  1799
#
# Found for term_id =  368660  doc_id =  1799
#
# Found for term_id =  236802  doc_id =  1799
#
# Found for term_id =  489397  doc_id =  1799
#
# Found for term_id =  837713  doc_id =  1799
#
# Found for term_id =  310069  doc_id =  1799
#
# Found for term_id =  16569  doc_id =  1799
#
# Found for term_id =  978679  doc_id =  1799
#
# Found for term_id =  47814  doc_id =  1799
#
# Found for term_id =  918302  doc_id =  1799
#
# Found for term_id =  889318  doc_id =  1799
#
# Found for term_id =  779819  doc_id =  1799
#
# Found for term_id =  929518  doc_id =  1799
#
# Found for term_id =  158256  doc_id =  1799
#
# Found for term_id =  463074  doc_id =  1799
#
# Found for term_id =  857554  doc_id =  1799
#
# Found for term_id =  345675  doc_id =  1799
#
# Found for term_id =  345675  doc_id =  1799
#
# Found for term_id =  607228  doc_id =  1799
#
# Found for term_id =  706154  doc_id =  1799
#
# Found for term_id =  807601  doc_id =  1799
#
# Found for term_id =  438323  doc_id =  1799
#
# Found for term_id =  825820  doc_id =  1799
#
# Found for term_id =  308689  doc_id =  1799
#
# Found for term_id =  51983  doc_id =  1799
#
# Found for term_id =  51983  doc_id =  1799
#
# Found for term_id =  451014  doc_id =  1799
#
# Found for term_id =  852425  doc_id =  1799
#
# Found for term_id =  75858  doc_id =  1799
#
# Found for term_id =  405095  doc_id =  1799
#
# Found for term_id =  659405  doc_id =  1799
#
# Found for term_id =  659405  doc_id =  1799
#
# Found for term_id =  751207  doc_id =  1799
#
# Found for term_id =  460514  doc_id =  1799
#
# Found for term_id =  107714  doc_id =  1799
#
# Found for term_id =  340641  doc_id =  1799
#
# Found for term_id =  100105  doc_id =  1799
#
# Found for term_id =  174357  doc_id =  1799
#
# Found for term_id =  444535  doc_id =  1799
#
# Found for term_id =  491535  doc_id =  1799
#
# Found for term_id =  247726  doc_id =  1799
#
# Found for term_id =  432424  doc_id =  1799
#
# Found for term_id =  208555  doc_id =  1799
#
# Found for term_id =  967330  doc_id =  1799
#
# Found for term_id =  623814  doc_id =  1799
#
# Found for term_id =  675254  doc_id =  1799
#
# Found for term_id =  868675  doc_id =  1799
#
# Found for term_id =  278221  doc_id =  1799
#
# Found for term_id =  281469  doc_id =  1799
#
# Found for term_id =  76565  doc_id =  1799
#
# Found for term_id =  686192  doc_id =  1799
#
# Found for term_id =  296739  doc_id =  1799
#
# Found for term_id =  422377  doc_id =  1799
#
# Found for term_id =  379267  doc_id =  1799
#
# Found for term_id =  191447  doc_id =  1799
#
# Found for term_id =  805649  doc_id =  1799
#
# Found for term_id =  349007  doc_id =  1799
#
# Found for term_id =  97946  doc_id =  1799
#
# Found for term_id =  94900  doc_id =  1799
#
# Found for term_id =  595952  doc_id =  1799
#
# Found for term_id =  948599  doc_id =  1799
#
# Found for term_id =  623660  doc_id =  1799
#
# Found for term_id =  271326  doc_id =  1799
#
# Found for term_id =  325842  doc_id =  1799
#
# Found for term_id =  547374  doc_id =  1799
#
# Found for term_id =  595988  doc_id =  1799
#
# Found for term_id =  499926  doc_id =  1799
#
# Found for term_id =  502717  doc_id =  1799
#
# Found for term_id =  456636  doc_id =  1799
#
# Found for term_id =  260089  doc_id =  1799
#
# Found for term_id =  802634  doc_id =  1799
#
# Found for term_id =  802634  doc_id =  1799
#
# Found for term_id =  808094  doc_id =  1799
#
# Found for term_id =  385955  doc_id =  1799
#
# Found for term_id =  252810  doc_id =  1799
#
# Found for term_id =  746796  doc_id =  1799
#
# Found for term_id =  430330  doc_id =  1799
#
# Found for term_id =  697760  doc_id =  1799
#
# Found for term_id =  697760  doc_id =  1799
#
# Found for term_id =  436273  doc_id =  1799
#
# Found for term_id =  430292  doc_id =  1799
#
# Found for term_id =  29577  doc_id =  1799
#
# Found for term_id =  262092  doc_id =  1799
#
# Found for term_id =  559204  doc_id =  1799
#
# Found for term_id =  943426  doc_id =  1799
#
# Found for term_id =  798225  doc_id =  1799
#
# Found for term_id =  750534  doc_id =  1799
#
# Found for term_id =  717395  doc_id =  1799
#
# Found for term_id =  517056  doc_id =  1799
#
# Found for term_id =  540089  doc_id =  1799
#
# Found for term_id =  635609  doc_id =  1799
#
# Found for term_id =  632632  doc_id =  1799
#
# Found for term_id =  449754  doc_id =  1799
#
# Found for term_id =  810567  doc_id =  1799
#
# Found for term_id =  188285  doc_id =  1799
#
# Found for term_id =  61318  doc_id =  1799
#
# Found for term_id =  951404  doc_id =  1799
#
# Found for term_id =  281494  doc_id =  1799
#
# Found for term_id =  730448  doc_id =  1799
#
# Found for term_id =  622825  doc_id =  1799
#
# Found for term_id =  508366  doc_id =  1799
#
# Found for term_id =  140624  doc_id =  1799
#
# Found for term_id =  104810  doc_id =  1799
#
# Found for term_id =  235607  doc_id =  1799
#
# Found for term_id =  114606  doc_id =  1799
#
# Found for term_id =  869095  doc_id =  1799
#
# Found for term_id =  513330  doc_id =  1799
#
# Found for term_id =  729775  doc_id =  1799
#
# Found for term_id =  348342  doc_id =  1799
#
# Found for term_id =  241604  doc_id =  1799
#
# Found for term_id =  241604  doc_id =  1799
#
# Found for term_id =  840857  doc_id =  1799
#
# Found for term_id =  881857  doc_id =  1799
#
# Found for term_id =  340298  doc_id =  1799
#
# Found for term_id =  515184  doc_id =  1799
#
# Found for term_id =  325447  doc_id =  1799
#
# Found for term_id =  263813  doc_id =  1799
#
# Found for term_id =  817553  doc_id =  1799
#
# Found for term_id =  493434  doc_id =  1799
#
# Found for term_id =  752311  doc_id =  1799
#
# Found for term_id =  61311  doc_id =  1799
#
# Found for term_id =  960808  doc_id =  1799
#
# Found for term_id =  293567  doc_id =  1799
#
# Found for term_id =  948041  doc_id =  1799
#
# Found for term_id =  373736  doc_id =  1799
#
# Found for term_id =  941926  doc_id =  1799
#
# Found for term_id =  941926  doc_id =  1799
#
# Found for term_id =  153763  doc_id =  1799
#
# Found for term_id =  716541  doc_id =  1799
#
# Found for term_id =  848559  doc_id =  1799
#
# Found for term_id =  22484  doc_id =  1799
#
# Found for term_id =  579494  doc_id =  1799
#
# Found for term_id =  849755  doc_id =  1799
#
# Found for term_id =  307613  doc_id =  1799
#
# Found for term_id =  255927  doc_id =  1799
#
# Found for term_id =  201050  doc_id =  1799
#
# Found for term_id =  352825  doc_id =  1799
#
# Found for term_id =  517742  doc_id =  1799
#
# Found for term_id =  603148  doc_id =  1799
#
# Found for term_id =  851696  doc_id =  1799
#
# Found for term_id =  674519  doc_id =  1799
#
# Found for term_id =  951312  doc_id =  1799
#
# Found for term_id =  296127  doc_id =  1799
#
# Found for term_id =  92128  doc_id =  1799
#
# Found for term_id =  870556  doc_id =  1799
#
# Found for term_id =  315832  doc_id =  1799
#
# Found for term_id =  889021  doc_id =  1799
#
# Found for term_id =  95595  doc_id =  1799
#
# Found for term_id =  997803  doc_id =  1799
#
# Found for term_id =  498676  doc_id =  1799
#
# Found for term_id =  2267  doc_id =  1799
#
# Found for term_id =  982001  doc_id =  1799
#
# Found for term_id =  343403  doc_id =  1799
#
# Found for term_id =  735963  doc_id =  1799
#
# Found for term_id =  921721  doc_id =  1799
#
# Found for term_id =  578213  doc_id =  1799
#
# Found for term_id =  398631  doc_id =  1799
#
# Found for term_id =  821511  doc_id =  1799
#
# Found for term_id =  423919  doc_id =  1799
#
# Found for term_id =  393522  doc_id =  1799
#
# Found for term_id =  544216  doc_id =  1799
#
# Found for term_id =  544216  doc_id =  1799
#
# Found for term_id =  292146  doc_id =  1799
#
# Found for term_id =  901002  doc_id =  1799
#
# Found for term_id =  825790  doc_id =  1799
#
# Found for term_id =  34247  doc_id =  1799
#
# Found for term_id =  648102  doc_id =  1799
#
# Found for term_id =  257628  doc_id =  1799
#
# Found for term_id =  468020  doc_id =  1799
#
# Found for term_id =  874393  doc_id =  1799
#
# Found for term_id =  126709  doc_id =  1799
#
# Found for term_id =  964280  doc_id =  4489
#
# Found for term_id =  972928  doc_id =  4489
#
# Found for term_id =  236802  doc_id =  4489
#
# Found for term_id =  489397  doc_id =  4489
#
# Found for term_id =  519008  doc_id =  4489
#
# Found for term_id =  130300  doc_id =  4489
#
# Found for term_id =  819730  doc_id =  4489
#
# Found for term_id =  16569  doc_id =  4489
#
# Found for term_id =  175201  doc_id =  4489
#
# Found for term_id =  572260  doc_id =  4489
#
# Found for term_id =  977455  doc_id =  4489
#
# Found for term_id =  100090  doc_id =  4489
#
# Found for term_id =  300910  doc_id =  4489
#
# Found for term_id =  978679  doc_id =  4489
#
# Found for term_id =  918302  doc_id =  4489
#
# Found for term_id =  804503  doc_id =  4489
#
# Found for term_id =  782646  doc_id =  4489
#
# Found for term_id =  628417  doc_id =  4489
#
# Found for term_id =  628417  doc_id =  4489
#
# Found for term_id =  918845  doc_id =  4489
#
# Found for term_id =  929518  doc_id =  4489
#
# Found for term_id =  976635  doc_id =  4489
#
# Found for term_id =  976635  doc_id =  4489
#
# Found for term_id =  565014  doc_id =  4489
#
# Found for term_id =  345675  doc_id =  4489
#
# Found for term_id =  831684  doc_id =  4489
#
# Found for term_id =  807601  doc_id =  4489
#
# Found for term_id =  900411  doc_id =  4489
#
# Found for term_id =  438323  doc_id =  4489
#
# Found for term_id =  923367  doc_id =  4489
#
# Found for term_id =  825820  doc_id =  4489
#
# Found for term_id =  451014  doc_id =  4489
#
# Found for term_id =  843788  doc_id =  4489
#
# Found for term_id =  852425  doc_id =  4489
#
# Found for term_id =  346157  doc_id =  4489
#
# Found for term_id =  696584  doc_id =  4489
#
# Found for term_id =  107714  doc_id =  4489
#
# Found for term_id =  100105  doc_id =  4489
#
# Found for term_id =  491535  doc_id =  4489
#
# Found for term_id =  870296  doc_id =  4489
#
# Found for term_id =  737550  doc_id =  4489
#
# Found for term_id =  208555  doc_id =  4489
#
# Found for term_id =  623814  doc_id =  4489
#
# Found for term_id =  93823  doc_id =  4489
#
# Found for term_id =  375863  doc_id =  4489
#
# Found for term_id =  419071  doc_id =  4489
#
# Found for term_id =  422377  doc_id =  4489
#
# Found for term_id =  423892  doc_id =  4489
#
# Found for term_id =  11976  doc_id =  4489
#
# Found for term_id =  805649  doc_id =  4489
#
# Found for term_id =  662292  doc_id =  4489
#
# Found for term_id =  890229  doc_id =  4489
#
# Found for term_id =  586775  doc_id =  4489
#
# Found for term_id =  716310  doc_id =  4489
#
# Found for term_id =  891326  doc_id =  4489
#
# Found for term_id =  595952  doc_id =  4489
#
# Found for term_id =  363714  doc_id =  4489
#
# Found for term_id =  948599  doc_id =  4489
#
# Found for term_id =  152014  doc_id =  4489
#
# Found for term_id =  444380  doc_id =  4489
#
# Found for term_id =  276301  doc_id =  4489
#
# Found for term_id =  772220  doc_id =  4489
#
# Found for term_id =  325842  doc_id =  4489
#
# Found for term_id =  617539  doc_id =  4489
#
# Found for term_id =  859960  doc_id =  4489
#
# Found for term_id =  547374  doc_id =  4489
#
# Found for term_id =  462914  doc_id =  4489
#
# Found for term_id =  499926  doc_id =  4489
#
# Found for term_id =  502717  doc_id =  4489
#
# Found for term_id =  677813  doc_id =  4489
#
# Found for term_id =  330631  doc_id =  4489
#
# Found for term_id =  335359  doc_id =  4489
#
# Found for term_id =  612460  doc_id =  4489
#
# Found for term_id =  100216  doc_id =  4489
#
# Found for term_id =  686496  doc_id =  4489
#
# Found for term_id =  951580  doc_id =  4489
#
# Found for term_id =  430330  doc_id =  4489
#
# Found for term_id =  430330  doc_id =  4489
#
# Found for term_id =  156507  doc_id =  4489
#
# Found for term_id =  969298  doc_id =  4489
#
# Found for term_id =  107667  doc_id =  4489
#
# Found for term_id =  430292  doc_id =  4489
#
# Found for term_id =  199705  doc_id =  4489
#
# Found for term_id =  262092  doc_id =  4489
#
# Found for term_id =  359329  doc_id =  4489
#
# Found for term_id =  943426  doc_id =  4489
#
# Found for term_id =  943426  doc_id =  4489
#
# Found for term_id =  750534  doc_id =  4489
#
# Found for term_id =  792392  doc_id =  4489
#
# Found for term_id =  717395  doc_id =  4489
#
# Found for term_id =  717395  doc_id =  4489
#
# Found for term_id =  341944  doc_id =  4489
#
# Found for term_id =  806232  doc_id =  4489
#
# Found for term_id =  493315  doc_id =  4489
#
# Found for term_id =  188285  doc_id =  4489
#
# Found for term_id =  951404  doc_id =  4489
#
# Found for term_id =  825637  doc_id =  4489
#
# Found for term_id =  283674  doc_id =  4489
#
# Found for term_id =  104810  doc_id =  4489
#
# Found for term_id =  985583  doc_id =  4489
#
# Found for term_id =  941906  doc_id =  4489
#
# Found for term_id =  792765  doc_id =  4489
#
# Found for term_id =  348342  doc_id =  4489
#
# Found for term_id =  129048  doc_id =  4489
#
# Found for term_id =  464359  doc_id =  4489
#
# Found for term_id =  840857  doc_id =  4489
#
# Found for term_id =  840857  doc_id =  4489
#
# Found for term_id =  594947  doc_id =  4489
#
# Found for term_id =  39771  doc_id =  4489
#
# Found for term_id =  511995  doc_id =  4489
#
# Found for term_id =  977456  doc_id =  4489
#
# Found for term_id =  556071  doc_id =  4489
#
# Found for term_id =  431320  doc_id =  4489
#
# Found for term_id =  325049  doc_id =  4489
#
# Found for term_id =  340298  doc_id =  4489
#
# Found for term_id =  381627  doc_id =  4489
#
# Found for term_id =  473925  doc_id =  4489
#
# Found for term_id =  325447  doc_id =  4489
#
# Found for term_id =  292275  doc_id =  4489
#
# Found for term_id =  40979  doc_id =  4489
#
# Found for term_id =  93617  doc_id =  4489
#
# Found for term_id =  914202  doc_id =  4489
#
# Found for term_id =  752311  doc_id =  4489
#
# Found for term_id =  929814  doc_id =  4489
#
# Found for term_id =  293567  doc_id =  4489
#
# Found for term_id =  948041  doc_id =  4489
#
# Found for term_id =  300389  doc_id =  4489
#
# Found for term_id =  921412  doc_id =  4489
#
# Found for term_id =  716541  doc_id =  4489
#
# Found for term_id =  716541  doc_id =  4489
#
# Found for term_id =  22484  doc_id =  4489
#
# Found for term_id =  77156  doc_id =  4489
#
# Found for term_id =  579494  doc_id =  4489
#
# Found for term_id =  447995  doc_id =  4489
#
# Found for term_id =  569714  doc_id =  4489
#
# Found for term_id =  778526  doc_id =  4489
#
# Found for term_id =  81396  doc_id =  4489
#
# Found for term_id =  81396  doc_id =  4489
#
# Found for term_id =  576578  doc_id =  4489
#
# Found for term_id =  201050  doc_id =  4489
#
# Found for term_id =  403204  doc_id =  4489
#
# Found for term_id =  674519  doc_id =  4489
#
# Found for term_id =  384056  doc_id =  4489
#
# Found for term_id =  92128  doc_id =  4489
#
# Found for term_id =  78543  doc_id =  4489
#
# Found for term_id =  258279  doc_id =  4489
#
# Found for term_id =  100384  doc_id =  4489
#
# Found for term_id =  870556  doc_id =  4489
#
# Found for term_id =  195053  doc_id =  4489
#
# Found for term_id =  997803  doc_id =  4489
#
# Found for term_id =  498676  doc_id =  4489
#
# Found for term_id =  807958  doc_id =  4489
#
# Found for term_id =  984247  doc_id =  4489
#
# Found for term_id =  984247  doc_id =  4489
#
# Found for term_id =  2267  doc_id =  4489
#
# Found for term_id =  670235  doc_id =  4489
#
# Found for term_id =  448217  doc_id =  4489
#
# Found for term_id =  856589  doc_id =  4489
#
# Found for term_id =  398631  doc_id =  4489
#
# Found for term_id =  423919  doc_id =  4489
#
# Found for term_id =  765261  doc_id =  4489
#
# Found for term_id =  61249  doc_id =  4489
#
# Found for term_id =  393522  doc_id =  4489
#
# Found for term_id =  303766  doc_id =  4489
#
# Found for term_id =  292146  doc_id =  4489
#
# Found for term_id =  901002  doc_id =  4489
#
# Found for term_id =  257628  doc_id =  4489
#
# Found for term_id =  468020  doc_id =  4489
#
# Found for term_id =  874393  doc_id =  4489
#
# Found for term_id =  688473  doc_id =  4489
# Found for term_id =  383262  doc_id =  2790
#
# Found for term_id =  960992  doc_id =  2790
#
# Found for term_id =  960992  doc_id =  2790
#
# Found for term_id =  960992  doc_id =  2790
#
# Found for term_id =  960992  doc_id =  2790
#
# Found for term_id =  960992  doc_id =  2790
#
# Found for term_id =  583925  doc_id =  2790
#
# Found for term_id =  881768  doc_id =  2790
#
# Found for term_id =  512585  doc_id =  2790
#
# Found for term_id =  675585  doc_id =  2790
#
# Found for term_id =  243013  doc_id =  2790
#
# Found for term_id =  243013  doc_id =  2790
#
# Found for term_id =  964280  doc_id =  2790
#
# Found for term_id =  964280  doc_id =  2790
#
# Found for term_id =  150734  doc_id =  2790
#
# Found for term_id =  103205  doc_id =  2790
#
# Found for term_id =  784426  doc_id =  2790
#
# Found for term_id =  784426  doc_id =  2790
#
# Found for term_id =  699864  doc_id =  2790
#
# Found for term_id =  133999  doc_id =  2790
#
# Found for term_id =  904436  doc_id =  2790
#
# Found for term_id =  765157  doc_id =  2790
#
# Found for term_id =  765157  doc_id =  2790
#
# Found for term_id =  514281  doc_id =  2790
#
# Found for term_id =  236802  doc_id =  2790
#
# Found for term_id =  154201  doc_id =  2790
#
# Found for term_id =  489397  doc_id =  2790
#
# Found for term_id =  489397  doc_id =  2790
#
# Found for term_id =  100585  doc_id =  2790
#
# Found for term_id =  534036  doc_id =  2790
#
# Found for term_id =  534036  doc_id =  2790
#
# Found for term_id =  27356  doc_id =  2790
#
# Found for term_id =  606798  doc_id =  2790
#
# Found for term_id =  786554  doc_id =  2790
#
# Found for term_id =  113761  doc_id =  2790
#
# Found for term_id =  951202  doc_id =  2790
#
# Found for term_id =  365431  doc_id =  2790
#
# Found for term_id =  970308  doc_id =  2790
#
# Found for term_id =  277016  doc_id =  2790
#
# Found for term_id =  591563  doc_id =  2790
#
# Found for term_id =  16569  doc_id =  2790
#
# Found for term_id =  175201  doc_id =  2790
#
# Found for term_id =  38735  doc_id =  2790
#
# Found for term_id =  38735  doc_id =  2790
#
# Found for term_id =  977455  doc_id =  2790
#
# Found for term_id =  978679  doc_id =  2790
#
# Found for term_id =  47814  doc_id =  2790
#
# Found for term_id =  47814  doc_id =  2790
#
# Found for term_id =  169434  doc_id =  2790
#
# Found for term_id =  526846  doc_id =  2790
#
# Found for term_id =  804503  doc_id =  2790
#
# Found for term_id =  889318  doc_id =  2790
#
# Found for term_id =  949748  doc_id =  2790
#
# Found for term_id =  137547  doc_id =  2790
#
# Found for term_id =  137547  doc_id =  2790
#
# Found for term_id =  892701  doc_id =  2790
#
# Found for term_id =  917058  doc_id =  2790
#
# Found for term_id =  779819  doc_id =  2790
#
# Found for term_id =  675338  doc_id =  2790
#
# Found for term_id =  782646  doc_id =  2790
#
# Found for term_id =  628417  doc_id =  2790
#
# Found for term_id =  628417  doc_id =  2790
#
# Found for term_id =  534445  doc_id =  2790
#
# Found for term_id =  69158  doc_id =  2790
#
# Found for term_id =  158256  doc_id =  2790
#
# Found for term_id =  976635  doc_id =  2790
#
# Found for term_id =  976635  doc_id =  2790
#
# Found for term_id =  565014  doc_id =  2790
#
# Found for term_id =  857554  doc_id =  2790
#
# Found for term_id =  345675  doc_id =  2790
#
# Found for term_id =  345675  doc_id =  2790
#
# Found for term_id =  345675  doc_id =  2790
#
# Found for term_id =  272970  doc_id =  2790
#
# Found for term_id =  448299  doc_id =  2790
#
# Found for term_id =  535537  doc_id =  2790
#
# Found for term_id =  706154  doc_id =  2790
#
# Found for term_id =  831684  doc_id =  2790
#
# Found for term_id =  807601  doc_id =  2790
#
# Found for term_id =  438323  doc_id =  2790
#
# Found for term_id =  907207  doc_id =  2790
#
# Found for term_id =  924664  doc_id =  2790
#
# Found for term_id =  924664  doc_id =  2790
#
# Found for term_id =  825820  doc_id =  2790
#
# Found for term_id =  91577  doc_id =  2790
#
# Found for term_id =  912428  doc_id =  2790
#
# Found for term_id =  912428  doc_id =  2790
#
# Found for term_id =  450674  doc_id =  2790
#
# Found for term_id =  450674  doc_id =  2790
#
# Found for term_id =  806041  doc_id =  2790
#
# Found for term_id =  20506  doc_id =  2790
#
# Found for term_id =  199768  doc_id =  2790
#
# Found for term_id =  199768  doc_id =  2790
#
# Found for term_id =  535705  doc_id =  2790
#
# Found for term_id =  163149  doc_id =  2790
#
# Found for term_id =  451014  doc_id =  2790
#
# Found for term_id =  451014  doc_id =  2790
#
# Found for term_id =  219697  doc_id =  2790
#
# Found for term_id =  219697  doc_id =  2790
#
# Found for term_id =  843788  doc_id =  2790
#
# Found for term_id =  843788  doc_id =  2790
#
# Found for term_id =  884605  doc_id =  2790
#
# Found for term_id =  884605  doc_id =  2790
#
# Found for term_id =  852425  doc_id =  2790
#
# Found for term_id =  852425  doc_id =  2790
#
# Found for term_id =  435334  doc_id =  2790
#
# Found for term_id =  435334  doc_id =  2790
#
# Found for term_id =  75858  doc_id =  2790
#
# Found for term_id =  236919  doc_id =  2790
#
# Found for term_id =  405095  doc_id =  2790
#
# Found for term_id =  405095  doc_id =  2790
#
# Found for term_id =  346157  doc_id =  2790
#
# Found for term_id =  346157  doc_id =  2790
#
# Found for term_id =  388055  doc_id =  2790
#
# Found for term_id =  223626  doc_id =  2790
#
# Found for term_id =  44470  doc_id =  2790
#
# Found for term_id =  44470  doc_id =  2790
#
# Found for term_id =  44470  doc_id =  2790
#
# Found for term_id =  44470  doc_id =  2790
#
# Found for term_id =  460514  doc_id =  2790
#
# Found for term_id =  107714  doc_id =  2790
#
# Found for term_id =  934106  doc_id =  2790
#
# Found for term_id =  15302  doc_id =  2790
#
# Found for term_id =  15302  doc_id =  2790
#
# Found for term_id =  340641  doc_id =  2790
#
# Found for term_id =  340641  doc_id =  2790
#
# Found for term_id =  523969  doc_id =  2790
#
# Found for term_id =  771353  doc_id =  2790
#
# Found for term_id =  771353  doc_id =  2790
#
# Found for term_id =  771353  doc_id =  2790
#
# Found for term_id =  182647  doc_id =  2790
#
# Found for term_id =  147166  doc_id =  2790
#
# Found for term_id =  100105  doc_id =  2790
#
# Found for term_id =  191720  doc_id =  2790
#
# Found for term_id =  191720  doc_id =  2790
#
# Found for term_id =  191720  doc_id =  2790
#
# Found for term_id =  806729  doc_id =  2790
#
# Found for term_id =  517433  doc_id =  2790
#
# Found for term_id =  517433  doc_id =  2790
#
# Found for term_id =  517433  doc_id =  2790
#
# Found for term_id =  304224  doc_id =  2790
#
# Found for term_id =  444535  doc_id =  2790
#
# Found for term_id =  444535  doc_id =  2790
#
# Found for term_id =  444535  doc_id =  2790
#
# Found for term_id =  491535  doc_id =  2790
#
# Found for term_id =  432424  doc_id =  2790
#
# Found for term_id =  414308  doc_id =  2790
#
# Found for term_id =  115236  doc_id =  2790
#
# Found for term_id =  431063  doc_id =  2790
#
# Found for term_id =  431063  doc_id =  2790
#
# Found for term_id =  708292  doc_id =  2790
#
# Found for term_id =  110692  doc_id =  2790
#
# Found for term_id =  867410  doc_id =  2790
#
# Found for term_id =  496892  doc_id =  2790
#
# Found for term_id =  496892  doc_id =  2790
#
# Found for term_id =  496892  doc_id =  2790
#
# Found for term_id =  675254  doc_id =  2790
#
# Found for term_id =  170409  doc_id =  2790
#
# Found for term_id =  376749  doc_id =  2790
#
# Found for term_id =  280551  doc_id =  2790
#
# Found for term_id =  409554  doc_id =  2790
#
# Found for term_id =  409554  doc_id =  2790
#
# Found for term_id =  209398  doc_id =  2790
#
# Found for term_id =  278221  doc_id =  2790
#
# Found for term_id =  278221  doc_id =  2790
#
# Found for term_id =  177863  doc_id =  2790
#
# Found for term_id =  76565  doc_id =  2790
#
# Found for term_id =  76565  doc_id =  2790
#
# Found for term_id =  433604  doc_id =  2790
#
# Found for term_id =  986188  doc_id =  2790
#
# Found for term_id =  686192  doc_id =  2790
#
# Found for term_id =  167410  doc_id =  2790
#
# Found for term_id =  296739  doc_id =  2790
#
# Found for term_id =  15957  doc_id =  2790
#
# Found for term_id =  422377  doc_id =  2790
#
# Found for term_id =  823403  doc_id =  2790
#
# Found for term_id =  379267  doc_id =  2790
#
# Found for term_id =  93013  doc_id =  2790
#
# Found for term_id =  93013  doc_id =  2790
#
# Found for term_id =  93013  doc_id =  2790
#
# Found for term_id =  93013  doc_id =  2790
#
# Found for term_id =  975063  doc_id =  2790
#
# Found for term_id =  423892  doc_id =  2790
#
# Found for term_id =  191447  doc_id =  2790
#
# Found for term_id =  11976  doc_id =  2790
#
# Found for term_id =  805649  doc_id =  2790
#
# Found for term_id =  349007  doc_id =  2790
#
# Found for term_id =  78767  doc_id =  2790
#
# Found for term_id =  78767  doc_id =  2790
#
# Found for term_id =  78767  doc_id =  2790
#
# Found for term_id =  78767  doc_id =  2790
#
# Found for term_id =  438565  doc_id =  2790
#
# Found for term_id =  510442  doc_id =  2790
#
# Found for term_id =  586775  doc_id =  2790
#
# Found for term_id =  213828  doc_id =  2790
#
# Found for term_id =  878875  doc_id =  2790
#
# Found for term_id =  723949  doc_id =  2790
#
# Found for term_id =  29683  doc_id =  2790
#
# Found for term_id =  325842  doc_id =  2790
#
# Found for term_id =  67539  doc_id =  2790
#
# Found for term_id =  695339  doc_id =  2790
#
# Found for term_id =  547374  doc_id =  2790
#
# Found for term_id =  758289  doc_id =  2790
#
# Found for term_id =  499926  doc_id =  2790
#
# Found for term_id =  502717  doc_id =  2790
#
# Found for term_id =  417111  doc_id =  2790
#
# Found for term_id =  323323  doc_id =  2790
#
# Found for term_id =  323323  doc_id =  2790
#
# Found for term_id =  780038  doc_id =  2790
#
# Found for term_id =  802634  doc_id =  2790
#
# Found for term_id =  802634  doc_id =  2790
#
# Found for term_id =  808094  doc_id =  2790
#
# Found for term_id =  630382  doc_id =  2790
#
# Found for term_id =  368603  doc_id =  2790
#
# Found for term_id =  541807  doc_id =  2790
#
# Found for term_id =  971844  doc_id =  2790
#
# Found for term_id =  127050  doc_id =  2790
#
# Found for term_id =  127050  doc_id =  2790
#
# Found for term_id =  335359  doc_id =  2790
#
# Found for term_id =  951580  doc_id =  2790
#
# Found for term_id =  853849  doc_id =  2790
#
# Found for term_id =  430330  doc_id =  2790
#
# Found for term_id =  199048  doc_id =  2790
#
# Found for term_id =  697760  doc_id =  2790
#
# Found for term_id =  339807  doc_id =  2790
#
# Found for term_id =  886652  doc_id =  2790
#
# Found for term_id =  430292  doc_id =  2790
#
# Found for term_id =  406236  doc_id =  2790
#
# Found for term_id =  406236  doc_id =  2790
#
# Found for term_id =  359329  doc_id =  2790
#
# Found for term_id =  359329  doc_id =  2790
#
# Found for term_id =  359329  doc_id =  2790
#
# Found for term_id =  559204  doc_id =  2790
#
# Found for term_id =  559204  doc_id =  2790
#
# Found for term_id =  943426  doc_id =  2790
#
# Found for term_id =  798225  doc_id =  2790
#
# Found for term_id =  87006  doc_id =  2790
#
# Found for term_id =  750534  doc_id =  2790
#
# Found for term_id =  750534  doc_id =  2790
#
# Found for term_id =  750534  doc_id =  2790
#
# Found for term_id =  750534  doc_id =  2790
#
# Found for term_id =  115268  doc_id =  2790
#
# Found for term_id =  647529  doc_id =  2790
#
# Found for term_id =  341944  doc_id =  2790
#
# Found for term_id =  555344  doc_id =  2790
#
# Found for term_id =  555344  doc_id =  2790
#
# Found for term_id =  133969  doc_id =  2790
#
# Found for term_id =  133969  doc_id =  2790
#
# Found for term_id =  517056  doc_id =  2790
#
# Found for term_id =  517056  doc_id =  2790
#
# Found for term_id =  517056  doc_id =  2790
#
# Found for term_id =  120223  doc_id =  2790
#
# Found for term_id =  17898  doc_id =  2790
#
# Found for term_id =  540089  doc_id =  2790
#
# Found for term_id =  451987  doc_id =  2790
#
# Found for term_id =  321864  doc_id =  2790
#
# Found for term_id =  559696  doc_id =  2790
#
# Found for term_id =  635609  doc_id =  2790
#
# Found for term_id =  334905  doc_id =  2790
#
# Found for term_id =  404082  doc_id =  2790
#
# Found for term_id =  108133  doc_id =  2790
#
# Found for term_id =  108133  doc_id =  2790
#
# Found for term_id =  643802  doc_id =  2790
#
# Found for term_id =  343821  doc_id =  2790
#
# Found for term_id =  806232  doc_id =  2790
#
# Found for term_id =  187294  doc_id =  2790
#
# Found for term_id =  188285  doc_id =  2790
#
# Found for term_id =  951404  doc_id =  2790
#
# Found for term_id =  281494  doc_id =  2790
#
# Found for term_id =  281494  doc_id =  2790
#
# Found for term_id =  798675  doc_id =  2790
#
# Found for term_id =  897452  doc_id =  2790
#
# Found for term_id =  202953  doc_id =  2790
#
# Found for term_id =  369232  doc_id =  2790
#
# Found for term_id =  462431  doc_id =  2790
#
# Found for term_id =  115769  doc_id =  2790
#
# Found for term_id =  986380  doc_id =  2790
#
# Found for term_id =  36061  doc_id =  2790
#
# Found for term_id =  884682  doc_id =  2790
#
# Found for term_id =  966569  doc_id =  2790
#
# Found for term_id =  398458  doc_id =  2790
#
# Found for term_id =  848245  doc_id =  2790
#
# Found for term_id =  848245  doc_id =  2790
#
# Found for term_id =  590974  doc_id =  2790
#
# Found for term_id =  550512  doc_id =  2790
#
# Found for term_id =  440786  doc_id =  2790
#
# Found for term_id =  985583  doc_id =  2790
#
# Found for term_id =  381485  doc_id =  2790
#
# Found for term_id =  235607  doc_id =  2790
#
# Found for term_id =  114606  doc_id =  2790
#
# Found for term_id =  114606  doc_id =  2790
#
# Found for term_id =  150907  doc_id =  2790
#
# Found for term_id =  191232  doc_id =  2790
#
# Found for term_id =  191232  doc_id =  2790
#
# Found for term_id =  191232  doc_id =  2790
#
# Found for term_id =  941906  doc_id =  2790
#
# Found for term_id =  941906  doc_id =  2790
#
# Found for term_id =  792765  doc_id =  2790
#
# Found for term_id =  792765  doc_id =  2790
#
# Found for term_id =  585005  doc_id =  2790
#
# Found for term_id =  874400  doc_id =  2790
#
# Found for term_id =  874400  doc_id =  2790
#
# Found for term_id =  729775  doc_id =  2790
#
# Found for term_id =  348342  doc_id =  2790
#
# Found for term_id =  409569  doc_id =  2790
#
# Found for term_id =  721446  doc_id =  2790
#
# Found for term_id =  202166  doc_id =  2790
#
# Found for term_id =  202166  doc_id =  2790
#
# Found for term_id =  202166  doc_id =  2790
#
# Found for term_id =  129048  doc_id =  2790
#
# Found for term_id =  666814  doc_id =  2790
#
# Found for term_id =  464359  doc_id =  2790
#
# Found for term_id =  464359  doc_id =  2790
# ...
#
# Found for term_id =  448983  doc_id =  7572
#
# Found for term_id =  90011  doc_id =  7572
#
# Found for term_id =  398631  doc_id =  7572
#
# Found for term_id =  821511  doc_id =  7572
#
# Found for term_id =  393522  doc_id =  7572
#
# Found for term_id =  544216  doc_id =  7572
#
# Found for term_id =  544216  doc_id =  7572
#
# Found for term_id =  292146  doc_id =  7572
#
# Found for term_id =  846502  doc_id =  7572
#
# Found for term_id =  901002  doc_id =  7572
#
# Found for term_id =  405479  doc_id =  7572
#
# Found for term_id =  468020  doc_id =  7572
#
# Found for term_id =  932190  doc_id =  7572
#
# Found for term_id =  960992  doc_id =  1862
#
# Found for term_id =  964280  doc_id =  1862
#
# Found for term_id =  133999  doc_id =  1862
#
# Found for term_id =  494825  doc_id =  1862
#
# Found for term_id =  368660  doc_id =  1862
#
# Found for term_id =  236802  doc_id =  1862
#
# Found for term_id =  67080  doc_id =  1862
#
# Found for term_id =  489397  doc_id =  1862
#
# Found for term_id =  14910  doc_id =  1862
#
# Found for term_id =  970308  doc_id =  1862
#
# Found for term_id =  591563  doc_id =  1862
#
# Found for term_id =  16569  doc_id =  1862
#
# Found for term_id =  16569  doc_id =  1862
#
# Found for term_id =  175201  doc_id =  1862
#
# Found for term_id =  218252  doc_id =  1862
#
# Found for term_id =  300910  doc_id =  1862
#
# Found for term_id =  804503  doc_id =  1862
#
# Found for term_id =  392427  doc_id =  1862
#
# Found for term_id =  925441  doc_id =  1862
#
# Found for term_id =  745661  doc_id =  1862
#
# Found for term_id =  779819  doc_id =  1862
#
# Found for term_id =  929518  doc_id =  1862
#
# Found for term_id =  158256  doc_id =  1862
#
# Found for term_id =  158256  doc_id =  1862
#
# Found for term_id =  463074  doc_id =  1862
#
# Found for term_id =  749029  doc_id =  1862
#
# Found for term_id =  698629  doc_id =  1862
#
# Found for term_id =  857554  doc_id =  1862
#
# Found for term_id =  706154  doc_id =  1862
#
# Found for term_id =  807601  doc_id =  1862
#
# Found for term_id =  364401  doc_id =  1862
#
# Found for term_id =  438323  doc_id =  1862
#
# Found for term_id =  51983  doc_id =  1862
#
# Found for term_id =  450674  doc_id =  1862
#
# Found for term_id =  451014  doc_id =  1862
#
# Found for term_id =  843788  doc_id =  1862
#
# Found for term_id =  852425  doc_id =  1862
#
# Found for term_id =  75858  doc_id =  1862
#
# Found for term_id =  346157  doc_id =  1862
#
# Found for term_id =  718104  doc_id =  1862
#
# Found for term_id =  50768  doc_id =  1862
#
# Found for term_id =  74437  doc_id =  1862
#
# Found for term_id =  44470  doc_id =  1862
#
# Found for term_id =  107714  doc_id =  1862
#
# Found for term_id =  884410  doc_id =  1862
#
# Found for term_id =  897127  doc_id =  1862
#
# Found for term_id =  100105  doc_id =  1862
#
# Found for term_id =  34324  doc_id =  1862
#
# Found for term_id =  491535  doc_id =  1862
#
# Found for term_id =  864892  doc_id =  1862
#
# Found for term_id =  967330  doc_id =  1862
#
# Found for term_id =  76565  doc_id =  1862
#
# Found for term_id =  809177  doc_id =  1862
#
# Found for term_id =  686192  doc_id =  1862
#
# Found for term_id =  572649  doc_id =  1862
#
# Found for term_id =  572649  doc_id =  1862
#
# Found for term_id =  191447  doc_id =  1862
#
# Found for term_id =  627631  doc_id =  1862
#
# Found for term_id =  627631  doc_id =  1862
#
# Found for term_id =  627631  doc_id =  1862
#
# Found for term_id =  805649  doc_id =  1862
#
# Found for term_id =  349007  doc_id =  1862
#
# Found for term_id =  438565  doc_id =  1862
#
# Found for term_id =  510442  doc_id =  1862
#
# Found for term_id =  97946  doc_id =  1862
#
# Found for term_id =  595952  doc_id =  1862
#
# Found for term_id =  130173  doc_id =  1862
#
# Found for term_id =  97510  doc_id =  1862
#
# Found for term_id =  325842  doc_id =  1862
#
# Found for term_id =  67539  doc_id =  1862
#
# Found for term_id =  483031  doc_id =  1862
#
# Found for term_id =  522286  doc_id =  1862
#
# Found for term_id =  547374  doc_id =  1862
#
# Found for term_id =  543087  doc_id =  1862
#
# Found for term_id =  595988  doc_id =  1862
#
# Found for term_id =  499926  doc_id =  1862
#
# Found for term_id =  502717  doc_id =  1862
#
# Found for term_id =  502717  doc_id =  1862
#
# Found for term_id =  802634  doc_id =  1862
#
# Found for term_id =  433102  doc_id =  1862
#
# Found for term_id =  435680  doc_id =  1862
#
# Found for term_id =  612460  doc_id =  1862
#
# Found for term_id =  412792  doc_id =  1862
#
# Found for term_id =  836825  doc_id =  1862
#
# Found for term_id =  430292  doc_id =  1862
#
# Found for term_id =  359329  doc_id =  1862
#
# Found for term_id =  798225  doc_id =  1862
#
# Found for term_id =  750534  doc_id =  1862
#
# Found for term_id =  358216  doc_id =  1862
#
# Found for term_id =  967416  doc_id =  1862
#
# Found for term_id =  305929  doc_id =  1862
#
# Found for term_id =  647529  doc_id =  1862
#
# Found for term_id =  251747  doc_id =  1862
#
# Found for term_id =  540089  doc_id =  1862
#
# Found for term_id =  212841  doc_id =  1862
#
# Found for term_id =  188285  doc_id =  1862
#
# Found for term_id =  797388  doc_id =  1862
#
# Found for term_id =  426786  doc_id =  1862
#
# Found for term_id =  166133  doc_id =  1862
#
# Found for term_id =  550512  doc_id =  1862
#
# Found for term_id =  664643  doc_id =  1862
#
# Found for term_id =  664643  doc_id =  1862
#
# Found for term_id =  235607  doc_id =  1862
#
# Found for term_id =  305650  doc_id =  1862
#
# Found for term_id =  349578  doc_id =  1862
#
# Found for term_id =  403666  doc_id =  1862
#
# Found for term_id =  403666  doc_id =  1862
#
# Found for term_id =  403666  doc_id =  1862
#
# Found for term_id =  348342  doc_id =  1862
#
# Found for term_id =  325742  doc_id =  1862
#
# Found for term_id =  420789  doc_id =  1862
#
# Found for term_id =  591461  doc_id =  1862
#
# Found for term_id =  247024  doc_id =  1862
#
# Found for term_id =  448061  doc_id =  1862
#
# Found for term_id =  241604  doc_id =  1862
#
# Found for term_id =  241604  doc_id =  1862
#
# Found for term_id =  103634  doc_id =  1862
#
# Found for term_id =  986902  doc_id =  1862
#
# Found for term_id =  927640  doc_id =  1862
#
# Found for term_id =  685502  doc_id =  1862
#
# Found for term_id =  325049  doc_id =  1862
#
# Found for term_id =  340298  doc_id =  1862
#
# Found for term_id =  896094  doc_id =  1862
#
# Found for term_id =  450093  doc_id =  1862
#
# Found for term_id =  408902  doc_id =  1862
#
# Found for term_id =  227096  doc_id =  1862
#
# Found for term_id =  325447  doc_id =  1862
#
# Found for term_id =  817553  doc_id =  1862
#
# Found for term_id =  749125  doc_id =  1862
#
# Found for term_id =  59236  doc_id =  1862
#
# Found for term_id =  93617  doc_id =  1862
#
# Found for term_id =  752311  doc_id =  1862
#
# Found for term_id =  7940  doc_id =  1862
#
# Found for term_id =  960808  doc_id =  1862
#
# Found for term_id =  948041  doc_id =  1862
#
# Found for term_id =  147999  doc_id =  1862
#
# Found for term_id =  300389  doc_id =  1862
#
# Found for term_id =  133945  doc_id =  1862
#
# Found for term_id =  921412  doc_id =  1862
#
# Found for term_id =  80677  doc_id =  1862
#
# Found for term_id =  596702  doc_id =  1862
#
# Found for term_id =  603701  doc_id =  1862
#
# Found for term_id =  43086  doc_id =  1862
#
# Found for term_id =  848559  doc_id =  1862
#
# Found for term_id =  447995  doc_id =  1862
#
# Found for term_id =  75010  doc_id =  1862
#
# Found for term_id =  674519  doc_id =  1862
#
# Found for term_id =  154767  doc_id =  1862
#
# Found for term_id =  92128  doc_id =  1862
#
# Found for term_id =  247002  doc_id =  1862
#
# Found for term_id =  95595  doc_id =  1862
#
# Found for term_id =  997803  doc_id =  1862
#
# Found for term_id =  498676  doc_id =  1862
#
# Found for term_id =  2267  doc_id =  1862
#
# Found for term_id =  261360  doc_id =  1862
#
# Found for term_id =  448983  doc_id =  1862
#
# Found for term_id =  735963  doc_id =  1862
#
# Found for term_id =  921721  doc_id =  1862
#
# Found for term_id =  578213  doc_id =  1862
#
# Found for term_id =  393522  doc_id =  1862
#
# Found for term_id =  404693  doc_id =  1862
#
# Found for term_id =  303766  doc_id =  1862
#
# Found for term_id =  901002  doc_id =  1862
#
# Found for term_id =  526464  doc_id =  1862
#
# Found for term_id =  468020  doc_id =  1862
#
# Found for term_id =  932204  doc_id =  1862
# Found for term_id =  960992  doc_id =  267
#
# Found for term_id =  964280  doc_id =  267
#
# Found for term_id =  984367  doc_id =  267
#
# Found for term_id =  404392  doc_id =  267
#
# Found for term_id =  236802  doc_id =  267
#
# Found for term_id =  489397  doc_id =  267
#
# Found for term_id =  95154  doc_id =  267
#
# Found for term_id =  27356  doc_id =  267
#
# Found for term_id =  837713  doc_id =  267
#
# Found for term_id =  591563  doc_id =  267
#
# Found for term_id =  16569  doc_id =  267
#
# Found for term_id =  175201  doc_id =  267
#
# Found for term_id =  300910  doc_id =  267
#
# Found for term_id =  580255  doc_id =  267
#
# Found for term_id =  801876  doc_id =  267
#
# Found for term_id =  749029  doc_id =  267
#
# Found for term_id =  24822  doc_id =  267
#
# Found for term_id =  807601  doc_id =  267
#
# Found for term_id =  438323  doc_id =  267
#
# Found for term_id =  825820  doc_id =  267
#
# Found for term_id =  825820  doc_id =  267
#
# Found for term_id =  825820  doc_id =  267
#
# Found for term_id =  451014  doc_id =  267
#
# Found for term_id =  852425  doc_id =  267
#
# Found for term_id =  346157  doc_id =  267
#
# Found for term_id =  388055  doc_id =  267
#
# Found for term_id =  223626  doc_id =  267
#
# Found for term_id =  107714  doc_id =  267
#
# Found for term_id =  185942  doc_id =  267
#
# Found for term_id =  71799  doc_id =  267
#
# Found for term_id =  100105  doc_id =  267
#
# Found for term_id =  491535  doc_id =  267
#
# Found for term_id =  579591  doc_id =  267
#
# Found for term_id =  167410  doc_id =  267
#
# Found for term_id =  419071  doc_id =  267
#
# Found for term_id =  975063  doc_id =  267
#
# Found for term_id =  805649  doc_id =  267
#
# Found for term_id =  866308  doc_id =  267
#
# Found for term_id =  64337  doc_id =  267
#
# Found for term_id =  325842  doc_id =  267
#
# Found for term_id =  325979  doc_id =  267
#
# Found for term_id =  499926  doc_id =  267
#
# Found for term_id =  502717  doc_id =  267
#
# Found for term_id =  39928  doc_id =  267
#
# Found for term_id =  612460  doc_id =  267
#
# Found for term_id =  893464  doc_id =  267
#
# Found for term_id =  88373  doc_id =  267
#
# Found for term_id =  430292  doc_id =  267
#
# Found for term_id =  291732  doc_id =  267
#
# Found for term_id =  637433  doc_id =  267
#
# Found for term_id =  296821  doc_id =  267
#
# Found for term_id =  404082  doc_id =  267
#
# Found for term_id =  187294  doc_id =  267
#
# Found for term_id =  322124  doc_id =  267
#
# Found for term_id =  685569  doc_id =  267
#
# Found for term_id =  188285  doc_id =  267
#
# Found for term_id =  369232  doc_id =  267
#
# Found for term_id =  871711  doc_id =  267
#
# Found for term_id =  114606  doc_id =  267
#
# Found for term_id =  348342  doc_id =  267
#
# Found for term_id =  904246  doc_id =  267
#
# Found for term_id =  28377  doc_id =  267
#
# Found for term_id =  117128  doc_id =  267
#
# Found for term_id =  340298  doc_id =  267
#
# Found for term_id =  325447  doc_id =  267
#
# Found for term_id =  535047  doc_id =  267
#
# Found for term_id =  752311  doc_id =  267
#
# Found for term_id =  752311  doc_id =  267
#
# Found for term_id =  929814  doc_id =  267
#
# Found for term_id =  302324  doc_id =  267
#
# Found for term_id =  960808  doc_id =  267
#
# Found for term_id =  948041  doc_id =  267
#
# Found for term_id =  147999  doc_id =  267
#
# Found for term_id =  877552  doc_id =  267
#
# Found for term_id =  652184  doc_id =  267
#
# Found for term_id =  652184  doc_id =  267
#
# Found for term_id =  73701  doc_id =  267
#
# Found for term_id =  201050  doc_id =  267
#
# Found for term_id =  192772  doc_id =  267
#
# Found for term_id =  674519  doc_id =  267
#
# Found for term_id =  92128  doc_id =  267
#
# Found for term_id =  997803  doc_id =  267
#
# Found for term_id =  2267  doc_id =  267
#
# Found for term_id =  221584  doc_id =  267
#
# Found for term_id =  393522  doc_id =  267
#
# Found for term_id =  151570  doc_id =  267
#
# Found for term_id =  301308  doc_id =  267
#
# Found for term_id =  754997  doc_id =  267
#
# Found for term_id =  303766  doc_id =  267
#
# Found for term_id =  468020  doc_id =  267
# hashed_ii =  {'383262': {'6616': [0], '5963': [0], '2790': [0], '5256': [0]}, '960992': {'6616': [1], '4935': [0, 1], '2613': [0], '1799': [0], '2790': [1, 2, 3, 4, 5], '7640': [0], '4900': [0], '1862': [0], '267': [0]}, '583925': {'6616': [2], '2790': [6], '1156': [0], '7572': [0]}, '152145': {'6616': [3], '1156': [3]}, '243013': {'6616': [4], '4935': [2, 3], '2790': [17, 18], '3718': [5], '5256': [3], '1156': [8], '719': [16]}, '964280': {'6616': [5], '4935': [4], '2613': [3], '5963': [4], '1799': [5], '4489': [2], '2790': [20, 21], '3718': [6], '5256': [4], '1156': [12], '719': [17], '7640': [1], '7114': [4], '4900': [1], '7572': [3], '1862': [1], '267': [1]}, '133999': {'6616': [6], '4935': [9], '2790': [31], '1862': [2]}, '239736': {'6616': [7]}, '208567': {'6616': [8]}, '801954': {'6616': [9], '4935': [13], '2613': [5], '5963': [11], '3718': [12], '7572': [12]}, '318302': {'6616': [10]}, '690504': {'6616': [11]}, '236802': {'6616': [12], '4935': [15], '2613': [6], '5963': [16], '1799': [17], '4489': [12], '2790': [45], '3718': [17], '5256': [14], '4900': [2], '7572': [16], '1862': [6], '267': [4]}, '489397': {'6616': [13], '4935': [17], '2613': [8], '5963': [17], '1799': [18], '4489': [13], '2790': [49, 50], '3718': [24], '5256': [15], '1156': [32], '719': [48], '7640': [10], '7114': [10], '4900': [3], '7572': [19], '1862': [8], '267': [6]}, '27356': {'6616': [14], '2790': [56], '5256': [18], '719': [53], '267': [8]}, '8605': {'6616': [15]}, '606798': {'6616': [16], '2790': [57], '7572': [22]}, '14910': {'6616': [17], '2613': [11], '5963': [22], '3718': [29], '1156': [44], '1862': [9]}, '907832': {'6616': [18]}, '6586': {'6616': [19]}, '819730': {'6616': [20], '4489': [19], '7114': [20]}, '175201': {'6616': [21], '4489': [21], '2790': [73], '5256': [24], '719': [86], '7114': [21], '7572': [26], '1862': [14], '267': [13]}, '884173': {'6616': [22]}, '956654': {'6616': [23]}, '38735': {'6616': [24], '5963': [30], '2790': [74, 75], '3718': [42], '7640': [15], '7114': [22]}, '360527': {'6616': [25]}, '598204': {'6616': [26]}, '580021': {'6616': [27]}, '969574': {'6616': [28], '719': [98]}, '308556': {'6616': [29]}, '308428': {'6616': [30]}, '300910': {'6616': [31], '4935': [32], '4489': [33], '1862': [16], '267': [14]}, '978679': {'6616': [32], '1799': [31], '4489': [36], '2790': [82], '5256': [32], '7114': [26]}, '607940': {'6616': [33]}, '918302': {'6616': [34], '1799': [34], '4489': [37], '3718': [47]}, '526846': {'6616': [35], '2613': [18], '5963': [42], '2790': [88], '3718': [49], '719': [105], '7572': [32]}, '580255': {'6616': [36], '5256': [35], '719': [106], '267': [15]}, '804503': {'6616': [37], '4489': [40], '2790': [89], '3718': [51], '5256': [36], '1862': [17]}, '889318': {'6616': [38], '1799': [36], '2790': [91], '5256': [37]}, '448408': {'6616': [39]}, '832899': {'6616': [40]}, '779819': {'6616': [41], '2613': [21], '5963': [54], '1799': [42], '2790': [103], '3718': [58], '1156': [77], '7114': [35], '7572': [38], '1862': [27]}, '353611': {'6616': [42]}, '865049': {'6616': [43]}, '40768': {'6616': [44]}, '853914': {'6616': [45]}, '280919': {'6616': [46]}, '343857': {'6616': [47], '1156': [95], '7572': [45]}, '589584': {'6616': [48], '5256': [48], '7640': [29]}, '345675': {'6616': [49], '2613': [29], '5963': [69], '1799': [53, 54], '4489': [69], '2790': [120, 121, 122], '3718': [72], '1156': [97, 98], '719': [168], '7572': [47]}, '448299': {'6616': [50], '2790': [125], '719': [171]}, '992234': {'6616': [51], '5963': [71]}, '807601': {'6616': [52], '4935': [60], '2613': [34], '5963': [75], '1799': [64], '4489': [72], '2790': [133], '3718': [80], '5256': [52], '1156': [108], '719': [185], '7640': [33], '7114': [50], '4900': [8], '7572': [52], '1862': [41], '267': [20]}, '900411': {'6616': [53], '4489': [74], '1156': [109]}, '438323': {'6616': [54], '4935': [61], '2613': [35], '5963': [76], '1799': [67], '4489': [75], '2790': [134], '3718': [81], '5256': [53], '1156': [110], '719': [186], '7640': [34], '7114': [51],  ...
# Happy Ending
# 3776

# %% [markdown]
# # Unhashed Inverted Index

# %%
def unhashed_term_index_write_to_file(term_index_dot_txt, dict_for_termid_and_postings):
    fh = open(term_index_dot_txt, "a+")
    for term_id, d_id in dict_for_termid_and_postings.items(): 
            lne = str(term_id) +"\t"+ str(len(d_id)) +"\t"+ str(d_id)
            fh.write(lne)
            fh.write('\n')
    fh.close()

# %%
def create_unhashed_inverted_index():
    # Get directory where all the .txt files are present.
    directory = get_directory_path("input")
    output_directory = get_directory_path("output")
    
    extension = ".txt"
    document_output_file_name = output_directory + "docid_unhashed" + extension
    term_output_file_name = output_directory + "termid_unhashed" + extension
    
    term_index_dot_txt = get_directory_path("output") + "term_index_unhashed" + extension
    
    # Load all stop words into a stop_list.
    stop_list_path = "/Users/imbilalbutt/Documents/Semesters/Semester 9/Information Retrieval/Assignment/stoplist.txt"
    stop_list = read_text_in_list_form(stop_list_path)
    
    files = find_all_files_in_directory(directory)
    
    list_of_docs = list() # for storing the ids of doc
    list_of_term_ids = list() # for storing the ids of all terms
    list_of_doc_and_terms = list() # for storing as tuples
    all_collection_of_words = list() # for storing all the unique words
    all_collection_of_word_ids = list() # for storing all the unique ids
    
    for i in range(0,int(len(files)/200)):
        file_path = directory + files[i] #+ extension # no need for extension in both cases of file
        all_text_without_html_headers = remove_html_headers(file_path) #str
        tokenized_words, count_of_words = tokenize_the_text(all_text_without_html_headers) #list
        tokenized_words_without_stop_words = remove_stop_words(tokenized_words, stop_list) #list
        stemmed_tokens_of_words = stem_words(tokenized_words_without_stop_words) #list 
        
        doc_id = random.randint(1,8000)
        
        word_id_postings_list = list()
        ## Append all words of a doc to list
        for w in range(0,len(stemmed_tokens_of_words)):     
            current_word = stemmed_tokens_of_words[w]
            
            term_id = random.randint(1,100000)
            while term_id in all_collection_of_word_ids:
                term_id = random.randint(1,100000)
            
            # if that word is not new, already present
            if (all_collection_of_words.count(current_word)) != 0:
                first_occurance = all_collection_of_words.index(current_word)
                term_id = all_collection_of_word_ids[first_occurance]
                #tupleX = (doc_id, str(term_id))
                #list_of_doc_and_terms.append(tupleX)
                list_of_docs.append(doc_id)
                list_of_term_ids.append(term_id)
            else:
                #list_of_term_ids.append(term_id)
                #tupleX = (doc_id, str(term_id))
                #list_of_doc_and_terms.append(tupleX[1])
                all_collection_of_words.append(current_word)
                all_collection_of_word_ids.append((term_id))
                list_of_docs.append(doc_id)
                list_of_term_ids.append(term_id)
            
        #list_of_docs.append(doc_id)
        docid_write_to_file(document_output_file_name,doc_id,files[i])
        # sort on the basis of term_ids
    #list_of_doc_and_terms.sort(key = operator.itemgetter(1))
    
    list_of_doc_and_terms = list(zip(list_of_docs, list_of_term_ids))
    list_of_doc_and_terms.sort(key = operator.itemgetter(1))
#     print((list_of_doc_and_terms))

    dict_for_termid_and_postings = create_postings_for_unhashed_ii(list_of_doc_and_terms)
    termid_write_to_file(term_output_file_name, all_collection_of_words, all_collection_of_word_ids)
    
    unhashed_term_index_write_to_file(term_index_dot_txt, dict_for_termid_and_postings)
    
    print("Happy Ending")
    print(len(all_collection_of_words))
#    print(dict_for_termid_and_postings)

# %% [markdown]
# To create hashed inverted index execute following function.

# %%
create_unhashed_inverted_index()

# %%
D = dict()

# %%
D[1] = 'A'
D[2] = 'B'
D[3] = 'C'

# %%
F = dict()

# %%
F[11] = ['G', 'L', 'M']
F[12] = 'H'
F[13] = 'I'

# %%
D[1] = F
T = F[11]
print((T))
# Out:
# ['G', 'L', 'M']

# %%
print(D)
# Out:
# {1: {11: ['G', 'L', 'M'], 12: 'H', 13: 'I'}, 2: 'B', 3: 'C'}

# %%
his = D[1]

# %%
print(his)
# Out:
# {11: ['G', 'L', 'M'], 12: 'H', 13: 'I'}

# %%
lst = his[11]
lst.append('N')
print(lst)
#his.update({11: 'Q'})
# Out:
# ['G', 'L', 'M', 'N']

# %%
his.update({11: lst})

# %%
print(his)
# Out:
# {11: ['G', 'L', 'M', 'N'], 12: 'H', 13: 'I'}

# %%
Y = dict()

# %%
Y[20] = 'LMO'
Y[21] = 'PQR'

# %%
his.update({11:Y})

# %%
print(his)

# %%
FooDiy = dict()

# %%
empty_list = list()
FooDiy = {'1' : empty_list}

# %%
x = FooDiy['1']

# %%
print(type(x))
# Out:
# <class 'list'>
